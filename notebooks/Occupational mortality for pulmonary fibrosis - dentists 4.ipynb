# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Men16_64_2.csv')
# Occupational mortality in England and Wales, 2000-2010 - Men age 16-64
# https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/healthandsocialcare/healthinequalities/adhocs/007958occupationalmortalityinenglandandwales2001to2010/mrp25652012pmrs200110.xls

# %%
df[(df['Occupation'] == 'Dental Technicians') & (df['Cause'] == 'Pulmonary fibrosis')]
# Out:
# Empty DataFrame
# Columns: [diagrp, Cause, jobcode, Occupation, Observed, Exp_Adj, PMR_Adj, Lower_Adj, Upper_Adj, Exp_Unadj, PMR_Unadj, Lower_Unadj, Upper_Unadj]
# Index: []

# %%
df[(df['Occupation'] == 'Dentists') & (df['Cause'] == 'Pulmonary fibrosis')]
# Out:
#        diagrp               Cause  jobcode Occupation  Observed  Exp_Adj  \
# 18748     132  Pulmonary fibrosis      160   Dentists         1     1.22
#
#        PMR_Adj  Lower_Adj  Upper_Adj  Exp_Unadj  PMR_Unadj  Lower_Unadj  \
# 18748     82.0        2.0      456.0       1.13       88.0          3.0
#
#        Upper_Unadj
# 18748        491.0

# %%
df[df['Cause'] == 'Pulmonary fibrosis'].sort_values(by='PMR_Adj', ascending=False)
# Out:
#        diagrp               Cause  jobcode  \
# 18755     132  Pulmonary fibrosis      230
# 18815     132  Pulmonary fibrosis     1000
# 18784     132  Pulmonary fibrosis      520
# 18850     132  Pulmonary fibrosis     1630
# 18800     132  Pulmonary fibrosis      740
# 18824     132  Pulmonary fibrosis     1170
# 18739     132  Pulmonary fibrosis       70
# 18829     132  Pulmonary fibrosis     1300
# 18821     132  Pulmonary fibrosis     1070
# 18860     132  Pulmonary fibrosis     1781
# 18764     132  Pulmonary fibrosis      320
# 18804     132  Pulmonary fibrosis      791
# 18834     132  Pulmonary fibrosis     1400
# 18835     132  Pulmonary fibrosis     1410
# 18817     132  Pulmonary fibrosis     1020
# 18845     132  Pulmonary fibrosis     1530
# 18853     132  Pulmonary fibrosis     1670
# 18825     132  Pulmonary fibrosis     1200
# 18857     132  Pulmonary fibrosis     1720
# 18794     132  Pulmonary fibrosis      620
# 18862     132  Pulmonary fibrosis     1820
# ...

# %%
df[(df['Cause'] == 'Pulmonary fibrosis') & (df['Observed'] > 30)].sort_values(by='PMR_Adj', ascending=False)
# Out:
#        diagrp               Cause  jobcode  \
# 18862     132  Pulmonary fibrosis     1820
# 18875     132  Pulmonary fibrosis     1980
# 18770     132  Pulmonary fibrosis      380
# 18738     132  Pulmonary fibrosis       60
# 18832     132  Pulmonary fibrosis     1370
# 18741     132  Pulmonary fibrosis       90
# 18827     132  Pulmonary fibrosis     1241
# 18830     132  Pulmonary fibrosis     1320
# 18776     132  Pulmonary fibrosis      440
# 18819     132  Pulmonary fibrosis     1040
# 18779     132  Pulmonary fibrosis      471
# 18863     132  Pulmonary fibrosis     1830
# 18789     132  Pulmonary fibrosis      580
# 18868     132  Pulmonary fibrosis     1900
# 18785     132  Pulmonary fibrosis      530
# 18791     132  Pulmonary fibrosis      600
# 18858     132  Pulmonary fibrosis     1740
#
#                                          Occupation  Observed  Exp_Adj  \
# 18862                           Bus & Coach Drivers        32    20.96
# ...

# %%
df[(df['Cause'] == 'Pulmonary fibrosis') & (df['Lower_Adj'] > 90)].sort_values(by='PMR_Adj', ascending=False)
# Out:
#        diagrp               Cause  jobcode  \
# 18755     132  Pulmonary fibrosis      230
# 18784     132  Pulmonary fibrosis      520
# 18850     132  Pulmonary fibrosis     1630
# 18853     132  Pulmonary fibrosis     1670
# 18862     132  Pulmonary fibrosis     1820
# 18875     132  Pulmonary fibrosis     1980
# 18738     132  Pulmonary fibrosis       60
#
#                                               Occupation  Observed  Exp_Adj  \
# 18755                                Driving Instructors        10     3.80
# 18784                                       Hairdressers         8     3.24
# 18850  Assemblers/Lineworkers (vehicles & other metal...        13     5.57
# 18853                                         Plasterers        15     9.02
# 18862                                Bus & Coach Drivers        32    20.96
# 18875                                    Other labourers        60    42.15
# 18738                                Sales Managers etc.        50    40.17
#
# ...
