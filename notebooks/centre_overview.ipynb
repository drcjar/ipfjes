# %%
import pandas as pd

# %%
df = pd.read_csv('../docs/centres.csv')

# %%
print ("{} organisations are participating".format(df.Organisation.count()))
print ("{} site visits have taken place".format(len(df[df.SIV == 'Y'])))
print ("{} C&Cs have been recieved".format(len(df[df['C&C'] == 'Y'])))
print ("{} centres have recruited at least one participant".format(len(df[df['Recruiting'] == 'Y'])))
# Out:
# 19 organisations are participating
# 13 site visits have taken place
# 12 C&Cs have been recieved
# 5 centres have recruited at least one participant

# %%
df
# Out:
#                                          Organisation  Centre ID SIV C&C  \
# 0               Heart of England NHS Foundation Trust          1   Y   Y
# 1                                  Morriston Hospital          2   Y   Y
# 2               Imperial College Healthcare NHS Trust         10   Y   Y
# 3           Nottingham University Hospitals NHS Trust          3   Y   Y
# 4          Southampton University Hospitals NHS Trust          4   Y   N
# 5             University Hospital of South Manchester          5   Y   Y
# 6              Papworth Hospital NHS Foundation Trust          6   N   N
# 7         Royal Devon and Exeter NHS Foundation Trust          7   Y   Y
# 8   Aintree University Hospitals NHS Foundation Trust          8   Y   Y
# 9                             North Bristol NHS Trust          9   Y   Y
# 10                           Aberdeen Royal Infirmary         11   Y   Y
# 11                            Glasgow Royal Infirmary         12   Y   Y
# ...

# %%
ls
# Out:
# 16SM3627 Sponsorship.pdf
# 2017.01.12 17-0021 PR Provisional Opinion.pdf
# 2017.02.11 17-0021 FIFO-3.pdf
# 5-year-age-bands.csv
# centres.csv
# centres.xlsx
# CHANGELOG.docx
# CHANGELOG.md
# cohorts1900-1960.doc
# cohorts1900-1960.odt
# exeter-pis-liverpool.aux
# exeter-pis-liverpool.log
# exeter-pis-liverpool.out
# exeter-pis-liverpool.pdf
# exeter-pis-liverpool.tex
# hra-minor-amendment-approval.pdf
# ICHTB approval letter IPF JES.pdf
# imperial.lco
# ipfjes-alog.xlsx
# ipfjes.bib*
# ipfjes.bib.bak*
# ipfjes.bib.sav*
# ipfjes-bundle-duplex-edition.pdf
# ipfjes-bundle-regular-edition.pdf
# ipfjes-centre-ids.csv
# ipfjes-centre.lco
# ipfjes-centre-welsh.lco
# ipfjes-consent.aux
# ipfjes-consent-edinburgh.pdf
# ipfjes-consent-edinburgh.tex
# ipfjes-consent-exeter.aux
# ipfjes-consent-exeter.log
# ipfjes-consent-exeter.out
# ipfjes-consent-exeter.pdf
# ipfjes-consent-exeter.tex
# ipfjes-consent-liverpool.aux
# ipfjes-consent-liverpool.log
# ipfjes-consent-liverpool.out
# ...
