# %% [markdown]
# # ipfjes monthly monitoring part 2

# %%
import pandas as pd
import psycopg2 as pg
import pandas.io.sql as psql
import datetime as dt
# %matplotlib inline

# %%
conn = pg.connect("dbname='carlplaying' user='drcjar' password='drcjar_is_not_fake'")

# %%
df = psql.read_sql("SELECT * FROM ipfjes_demographics", conn)

# %%
print(len(df))
# Out:
# 1005

# %%
df1 = psql.read_sql("SELECT * FROM ipfjes_studyparticipantdetails", conn)

# %%
print(len(df1))
# Out:
# 1005

# %%
df1[df1.participant_type.isnull()] # participants with no participant type
# Out:
# Empty DataFrame
# Columns: [id, created, updated, consistency_token, participant_type, site_ft, created_by_id, episode_id, site_fk_id, updated_by_id, comments, email_address, postal_address, want_updates]
# Index: []

# %%
df2 = psql.read_sql("SELECT * FROM ipfjes_removalreason", conn)

# %%
print(len(df2))
# Out:
# 1005

# %%
df1.participant_type.value_counts()
# Out:
# case       519
# control    486
# Name: participant_type, dtype: int64

# %%
df3 = df2[df2.reason_fk_id.notnull()]

# %%
len(df3)
# Out:
# 60

# %%
df3
# Out:
#         id created                           updated consistency_token  \
# 89      67    None  2017-10-12 16:28:53.408685+01:00          7be270bf
# 90      14    None  2017-10-12 16:36:50.673188+01:00          28629739
# 93      96    None  2017-10-19 10:34:33.416127+01:00          e8750282
# 149    156    None  2017-11-24 10:25:04.486385+00:00          167e947b
# 152     95    None                              None          8f6267d9
# 231    211    None  2018-01-23 18:24:33.224619+00:00          312d8e08
# 252      7    None                              None              carl
# 253     33    None                              None          10bd23bf
# 265    237    None  2018-02-08 14:12:50.905425+00:00          9dccc4db
# 266    242    None  2018-02-08 14:14:24.350733+00:00          d522e5d6
# 267    260    None  2018-02-08 14:44:54.857991+00:00          7843013c
# 442    329    None  2018-07-03 11:30:49.328257+01:00          0045a7a5
# 443    453    None  2018-07-03 14:41:08.210959+01:00          11bd3d78
# 451    396    None  2018-09-20 15:53:40.091760+01:00          83af76ad
# 452    410    None  2018-09-20 15:54:00.837158+01:00          461558ec
# 453    448    None  2018-09-20 15:54:20.123907+01:00          116e8b0e
# 548    470    None  2018-08-09 12:52:39.283385+01:00          495c8348
# 551    480    None  2018-08-09 13:57:11.143320+01:00          95741132
# 557    483    None  2018-08-13 13:31:00.927898+01:00          07a4843d
# 570    523    None  2018-08-21 14:00:35.334921+01:00          6cbdd23d
# 579    608    None  2018-08-31 14:18:45.785454+01:00          fa1e9267
# 580    598    None  2018-09-04 10:09:51.315392+01:00          0d4c31ba
# 581    603    None  2018-09-04 10:17:52.887437+01:00          161c613e
# 585    552    None  2018-09-07 10:17:32.801390+01:00          269a336f
# 586    550    None  2018-09-10 08:42:52.660756+01:00          77831bd9
# 591    502    None  2018-09-12 10:57:35.698360+01:00          7a8f0a86
# 594    493    None  2018-09-20 15:54:41.185175+01:00          810f9a96
# 595    497    None  2018-09-20 15:55:02.145749+01:00          89bd8a59
# 596    538    None  2018-10-05 13:59:30.864043+01:00          88b81068
# 597    622    None  2018-10-31 08:54:00.029019+00:00          8bf3e367
# 595                     None         502           3.0            4.0
# 596                     None         543           3.0            3.0
# 597                     None         627           3.0            3.0
# 605                     None         584           3.0            3.0
# 612                     None         390           1.0            4.0
# 613                     None         400           3.0            4.0
# 626                     None         637           1.0            3.0
# 628                     None         647           1.0            3.0
# 682                     None         680           2.0            4.0
# 686                     None         703           1.0            3.0
# 707                     None         729           1.0            3.0
# 723                     None         682           3.0            3.0
# 735                     None         767           1.0            3.0
# 746                     None         771           3.0            3.0
# 753                     None         673           3.0            3.0
# 799                     None         818           1.0            3.0
# 800                     None         753           3.0            3.0
# 811                     None         816           3.0            3.0
# 816                     None         837           1.0            3.0
# 820                     None         797           1.0            3.0
# 821                     None         820           1.0            3.0
# 834                     None         859           1.0            3.0
# 840                     None         868           1.0            3.0
# 886                     None         913           1.0            3.0
# 888                     None         875           1.0            3.0
# 891                     None         862           1.0            3.0
# 893                     None         870           2.0            3.0
# 897                     None         880           3.0            3.0
# 907                     None         861           3.0            3.0
# 986                     None         955           2.0            3.0
# 996                     None         972           1.0            3.0
# 1003                    None        1029           1.0            3.0
# 1004                    None         978           1.0            3.0

# %%
pd.merge(df1, df3, on='id').participant_type.value_counts() # number of pts exlcuded at interview
# nb this isn't correct since we're apparently losing not episodes that lack a participant type ?n=2
# Out:
# case       31
# control    28
# Name: participant_type, dtype: int64

# %%
pd.merge(df1, df3, on='id')
# Out:
#       id created_x                         updated_x consistency_token_x  \
# 0     14      None  2017-07-14 15:38:38.391768+01:00            c2505c20
# 1      7      None  2017-07-21 12:33:08.452850+01:00            7bebe383
# 2     95      None  2017-10-11 12:56:02.159228+01:00            07c55932
# 3     33      None  2017-08-16 11:03:00.042267+01:00            2a24f782
# 4     67      None  2017-09-08 11:13:51.480237+01:00            234c45d7
# 5     96      None  2017-10-12 13:56:11.326558+01:00            6652cda6
# 6    156      None  2017-11-23 15:19:31.534953+00:00            ab19dfc6
# 7    211      None  2017-12-22 13:16:54.830740+00:00            cd561ab5
# 8    242      None  2018-01-22 15:13:14.164227+00:00            901aadb6
# 9    237      None  2018-01-24 16:05:27.697276+00:00            cf79e85d
# 10   260      None  2018-02-02 15:50:32.482421+00:00            ef16a3bb
# 11   483      None  2018-06-13 14:26:46.352101+01:00            658bdfa0
# 12   329      None  2018-03-26 10:07:48.353675+01:00            1b795e2d
# 13   396      None  2018-05-14 16:21:28.976803+01:00            0d196fbc
# 14   410      None  2018-05-16 12:46:47.022732+01:00            76609d28
# 15   470      None  2018-06-05 15:03:46.101936+01:00            c5615806
# 16   385      None  2018-04-25 09:37:25.458131+01:00            0b2d4647
# 17   453      None  2018-05-29 11:56:57.395787+01:00            4ee3db48
# 18   395      None  2018-04-30 16:52:00.843711+01:00            bd1ac2ee
# 19   448      None  2018-06-04 15:36:21.787164+01:00            54562804
# 20   480      None  2018-06-19 12:21:28.626256+01:00            22385d28
# 21   493      None  2018-06-21 14:37:05.881114+01:00            5258889a
# 22   497      None  2018-06-27 15:25:03.248337+01:00            8c627acb
# 18             case                    None           395         6.0
# 19             case                    None           448        19.0
# 20             case                    None           480         4.0
# 21             case                    None           493         7.0
# 22             case                    None           497         4.0
# 23          control                    None           603         7.0
# 24          control                    None           579         6.0
# 25          control                    None           502         6.0
# 26             case                    None           608        21.0
# 27             case                    None           523         7.0
# 28             case                    None           550        19.0
# 29             case                    None           538        19.0
# 30             case                    None           552        19.0
# 31             case                    None           622        22.0
# 32             case                    None           632         4.0
# 33          control                    None           642         7.0
# 34          control                    None           668         7.0
# 35          control                    None           675        21.0
# 36             case                    None           677         6.0
# 37          control                    None           698         6.0
# 38          control                    None           724        15.0
# 39             case                    None           748         7.0
# 40             case                    None           766         8.0
# 41          control                    None           762         2.0
# 42          control                    None           792         2.0
# 43          control                    None           813         5.0
# 44          control                    None           811         5.0
# 45          control                    None           815        11.0
# 46          control                    None           832         6.0
# 47          control                    None           870         1.0
# 48             case                    None           857         7.0
# 49          control                    None           865         2.0
# 50          control                    None           854        14.0
# 51          control                    None           875         2.0
# 52          control                    None           863         1.0
# 53          control                    None           908        11.0
# 54          control                    None           856         7.0
# 55          control                    None           972         1.0
# 56          control                    None           950         8.0
# 57          control                    None           966        10.0
# 58             case                    None          1023         6.0
#
#     updated_by_id_x       ...         \
# 0                 3       ...
# 1                 3       ...
# 2                 3       ...
# 3                 3       ...
# 4                 3       ...
# 5                 3       ...
# 6                 3       ...
# 7                 3       ...
# 8                 3       ...
# 9                 3       ...
# 10                3       ...
# 11                4       ...
# 12                3       ...
# 13                3       ...
# 14                3       ...
# 15                3       ...
# 16                3       ...
# 17                4       ...
# 18                4       ...
# 19                4       ...
# 20                3       ...
# 21                4       ...
# 22                3       ...
# 23                4       ...
# 24                3       ...
# 25                3       ...
# 26                4       ...
# 27                1       ...
# 28                3       ...
# 29                3       ...
# 30                3       ...
# 31                3       ...
# 32                3       ...
# 33                3       ...
# 34                3       ...
# 35                3       ...
# 36                3       ...
# 37                3       ...
# 38                3       ...
# 39                3       ...
# 40                3       ...
# 41                3       ...
# 42                3       ...
# 43                3       ...
# 44                3       ...
# 45                3       ...
# 46                3       ...
# 47                3       ...
# 48                3       ...
# 49                3       ...
# 50                3       ...
# 51                3       ...
# 52                4       ...
# 53                3       ...
# 54                3       ...
# 55                3       ...
# 56                3       ...
# 57                3       ...
# 58                4       ...
#
#                                        postal_address want_updates created_y  \
# 0                                                               No      None
# 1                                             by post          Yes      None
# 2                                                              Yes      None
# 3                                                              Yes      None
# 4         43 Rodger Street, Treboth, Swansea. SA5 9AS          Yes      None
# 5                                                              Yes      None
# 6               19 Tomlinson Street, Liverpool L5 5EH          Yes      None
# 7   Silverdale, Banks Fee Lane, \nLongborough, Mor...          Yes      None
# 8                                                             None      None
# 9   56 Bishops Road, Leasingham, Sleaford, Linc. N...          Yes      None
# 10                                                             Yes      None
# 11  Rose Cottage, Mill Street, Gislingham, Eye. Su...          Yes      None
# 12                                                             Yes      None
# 13  4 Harpole Close, Swanwick, Alfreton. Derbyshir...          Yes      None
# 0             None           83          1.0              4.0
# 1             None           11          2.0              NaN
# 2             None           43          4.0              NaN
# 3             None           28          1.0              NaN
# 4             None           59          3.0              4.0
# 5             None          101          1.0              4.0
# 6             None          161          1.0              4.0
# 7             None          216          1.0              4.0
# 8             None          247          3.0              4.0
# 9             None          242          3.0              4.0
# 10            None          265          1.0              4.0
# 11            None          488          1.0              3.0
# 12            None          334          1.0              4.0
# 13            None          401          1.0              4.0
# 14            None          415          1.0              4.0
# 15            None          475          2.0              3.0
# 16            None          390          1.0              4.0
# 17            None          458          1.0              3.0
# 18            None          400          3.0              4.0
# 19            None          453          1.0              4.0
# 20            None          485          2.0              3.0
# 21            None          498          1.0              4.0
# 22            None          502          3.0              4.0
# 23            None          608          1.0              3.0
# 24            None          584          3.0              3.0
# 25            None          507          1.0              3.0
# 26            None          613          1.0              3.0
# 27            None          528          2.0              3.0
# 28            None          555          3.0              3.0
# 29            None          543          3.0              3.0
# 30            None          557          3.0              3.0
# 31            None          627          3.0              3.0
# 32            None          637          1.0              3.0
# 33            None          647          1.0              3.0
# 34            None          673          3.0              3.0
# 35            None          680          2.0              4.0
# 36            None          682          3.0              3.0
# 37            None          703          1.0              3.0
# 38            None          729          1.0              3.0
# 39            None          753          3.0              3.0
# 40            None          771          3.0              3.0
# 41            None          767          1.0              3.0
# 42            None          797          1.0              3.0
# 43            None          818          1.0              3.0
# 44            None          816          3.0              3.0
# 45            None          820          1.0              3.0
# 46            None          837          1.0              3.0
# 47            None          875          1.0              3.0
# 48            None          862          1.0              3.0
# 49            None          870          2.0              3.0
# 50            None          859          1.0              3.0
# 51            None          880          3.0              3.0
# 52            None          868          1.0              3.0
# 53            None          913          1.0              3.0
# 54            None          861          3.0              3.0
# 55            None          978          1.0              3.0
# 56            None          955          2.0              3.0
# 57            None          972          1.0              3.0
# 58            None         1029          1.0              3.0
#
# [59 rows x 22 columns]

# %%
df = pd.merge(df, df1, on='id')

# %%
df = df[~df.episode_id.isin(df3.episode_id)] # throw away excluded patients

# %%
df['centre'] = df.hospital_number.str[:2]

# %%
df.groupby('centre').participant_type.value_counts().unstack().sum().sum()
# Out:
# 944

# %%
df = df[~df.date_of_birth.isnull()] # throw away rows missing date of birth

# %%
df['years'] = ((dt.datetime.now() - pd.to_datetime(df.date_of_birth)).dt.days / 365).astype(int)

# %%
df['years'].hist()

# %%
df[df.participant_type == 'case'].years.hist()

# %%
df[df.participant_type == 'control'].years.hist()

# %%
df['agegroup']= pd.cut(df.years, range(25,100,5), 
                labels=[
                    '25 to 29',
                    '30 to 34',
                    '35 to 39',
                    '40 to 44',
                    '45 to 49',
                    '50 to 54',
                    '55 to 59',
                    '60 to 64',
                    '65 to 69',
                    '70 to 74',
                    '75 to 79',
                    '80 to 84',
                    '85 to 90',
                    '90 to 94'],
                right=False) # add age

# %%
centre_id = pd.read_csv('ipfjes-centre-ids.csv', index_col='Centre ID')
centre_lookup = centre_id['Organisation'].to_dict()

# %%
def centre_stats(centre):
    start_date = dt.date(2017, 6, 1)
    end_date = dt.date(2019, 8, 1)
    elapsed = (dt.date.today() - start_date).days
    remaining = (end_date - dt.date.today()).days

    print('{} ({})'.format(centre_lookup.get(int(centre)), centre))
    print('-----------------')
    
    recruited = df[df.centre == centre].id.count()
    cases = df[(df.centre == centre) & (df.participant_type == 'case')].id.count()
    controls = df[(df.centre == centre) & (df.participant_type == 'control')].id.count()
    print('{} enrolled in {} days ({} cases, {} controls) - {:.2f}/week \n{} in {}\
 days to go - {:.2f}/week '.format(recruited, elapsed, cases, controls, (recruited/elapsed*7),
                                (80 - recruited), remaining, (80 - recruited)/remaining*7))
    
    print('\n')
    print(df[df.centre == centre].groupby('participant_type').agegroup.value_counts(sort=False).unstack())
    print('\n')

# %%
# big dirty hack to make upper cat be 85+

df.agegroup.cat.categories = ['25 to 29', '30 to 34', '35 to 39', '40 to 44', '45 to 49', '50 to 54',
       '55 to 59', '60 to 64', '65 to 69', '70 to 74', '75 to 79', '80 to 84',
       '85+', '90 to 94']

df.loc[df.agegroup > "80 to 84", "agegroup"] = "85+"

# %%
centres = df.centre.unique()
centres.sort()
for centre in centres:
    try:
        centre_stats(centre) # because we have a pt with no case or control status
    except IndexError:
        continue
# Out:
# Heart of England NHS Foundation Trust (01)
# -----------------
# 81 enrolled in 820 days (43 cases, 38 controls) - 0.69/week
# -1 in -29 days to go - 0.24/week
#
#
# agegroup          50 to 54  55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  \
# participant_type
# case                     1         1         1         5        14         8
# control                  1         1         2         5        11         9
#
# agegroup          80 to 84  85+
# participant_type
# case                    11    2
# control                  6    3
#
#
# Morriston Hospital (02)
# -----------------
# 24 enrolled in 820 days (13 cases, 11 controls) - 0.20/week
# 56 in -29 days to go - -13.52/week
#
#
# agegroup          55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  80 to 84
# participant_type
# case                   1.0       1.0       3.0       NaN       5.0       3.0
# control                1.0       1.0       3.0       1.0       1.0       4.0
#
#
# Nottingham University Hospitals NHS Trust (03)
# -----------------
# 74 enrolled in 820 days (38 cases, 36 controls) - 0.63/week
# 6 in -29 days to go - -1.45/week
#
#
# agegroup          55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  \
# participant_type
# case                   1.0       1.0       2.0       9.0       8.0      10.0
# control                NaN       4.0       3.0      12.0       7.0       8.0
#
# agegroup          85+
# participant_type
# case              7.0
# control           2.0
#
#
# Southampton University Hospitals NHS Trust (04)
# -----------------
# 100 enrolled in 820 days (51 cases, 49 controls) - 0.85/week
# -20 in -29 days to go - 4.83/week
#
#
# agegroup          55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  \
# participant_type
# case                     1         6         3         7        14        10
# control                  1         6         2         7        12        11
#
# agegroup          85+
# participant_type
# case               10
# control            10
#
#
# University Hospital of South Manchester (05)
# -----------------
# 72 enrolled in 820 days (40 cases, 32 controls) - 0.61/week
# 8 in -29 days to go - -1.93/week
#
#
# agegroup          55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  \
# participant_type
# case                   1.0       3.0       7.0      10.0      11.0       5.0
# control                NaN       5.0      10.0       4.0       5.0       4.0
#
# agegroup          85+
# participant_type
# case              3.0
# control           4.0
#
#
# Papworth Hospital NHS Foundation Trust (06)
# -----------------
# 71 enrolled in 820 days (35 cases, 36 controls) - 0.61/week
# 9 in -29 days to go - -2.17/week
#
#
# agegroup          35 to 39  55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  \
# participant_type
# case                   NaN       1.0       2.0       4.0      10.0      10.0
# control                1.0       2.0       3.0       5.0      10.0      12.0
#
# agegroup          80 to 84  85+
# participant_type
# case                   5.0  3.0
# control                2.0  1.0
#
#
# Royal Devon and Exeter NHS Foundation Trust (07)
# -----------------
# 30 enrolled in 820 days (15 cases, 15 controls) - 0.26/week
# 50 in -29 days to go - -12.07/week
#
#
# agegroup          40 to 44  50 to 54  55 to 59  65 to 69  70 to 74  75 to 79  \
# participant_type
# case                   NaN       NaN       3.0       1.0       3.0       2.0
# control                1.0       1.0       2.0       1.0       3.0       5.0
#
# agegroup          80 to 84  85+
# participant_type
# case                   2.0  4.0
# control                1.0  1.0
#
#
# Aintree University Hospitals NHS Foundation Trust (08)
# -----------------
# 79 enrolled in 820 days (40 cases, 39 controls) - 0.67/week
# 1 in -29 days to go - -0.24/week
#
#
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  85+
# participant_type
# case                     2         6        11        10         7    4
# control                  1         8        13         7         5    5
#
#
# North Bristol NHS Trust (09)
# -----------------
# 60 enrolled in 820 days (31 cases, 29 controls) - 0.51/week
# 20 in -29 days to go - -4.83/week
#
#
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  85+
# participant_type
# case                     1         2         5        11         8    4
# control                  2         1         7         8         7    4
#
#
# Imperial College Healthcare NHS Trust (10)
# -----------------
# 90 enrolled in 820 days (21 cases, 69 controls) - 0.77/week
# -10 in -29 days to go - 2.41/week
#
#
# agegroup          30 to 34  50 to 54  55 to 59  60 to 64  65 to 69  70 to 74  \
# participant_type
# case                   NaN       NaN       NaN       NaN       1.0       4.0
# control                1.0       3.0       1.0       6.0      12.0      21.0
#
# agegroup          75 to 79  80 to 84  85+
# participant_type
# case                   5.0       5.0  6.0
# control               15.0       6.0  4.0
#
#
# Aberdeen Royal Infirmary (11)
# -----------------
# 21 enrolled in 820 days (12 cases, 9 controls) - 0.18/week
# 59 in -29 days to go - -14.24/week
#
#
# agegroup          50 to 54  55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  \
# participant_type
# case                   2.0       NaN       2.0       3.0       2.0       2.0
# control                NaN       2.0       NaN       2.0       2.0       1.0
#
# agegroup          80 to 84  85+
# participant_type
# case                   NaN  1.0
# control                1.0  1.0
#
#
# Glasgow Royal Infirmary (12)
# -----------------
# 7 enrolled in 820 days (4 cases, 3 controls) - 0.06/week
# 73 in -29 days to go - -17.62/week
#
#
# agegroup          55 to 59  60 to 64  65 to 69  70 to 74  75 to 79
# participant_type
# case                   1.0       1.0       1.0       NaN       1.0
# control                NaN       1.0       NaN       1.0       1.0
#
#
# Royal Infirmary of Edinburgh (13)
# -----------------
# 24 enrolled in 820 days (13 cases, 11 controls) - 0.20/week
# 56 in -29 days to go - -13.52/week
#
#
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  85+
# participant_type
# case                   2.0       NaN       3.0       4.0       2.0  2.0
# control                2.0       2.0       3.0       3.0       NaN  1.0
#
#
# The Newcastle Upon Tyne Hospitals NHS Foundation Trust (14)
# -----------------
# 36 enrolled in 820 days (20 cases, 16 controls) - 0.31/week
# 44 in -29 days to go - -10.62/week
#
#
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  85+
# participant_type
# case                   1.0       3.0       4.0       9.0       2.0  1.0
# control                NaN       4.0       5.0       3.0       3.0  1.0
#
#
# Taunton and Somerset NHS Foundation Trust (15)
# -----------------
# 28 enrolled in 820 days (15 cases, 13 controls) - 0.24/week
# 52 in -29 days to go - -12.55/week
#
#
# agegroup          55 to 59  60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  \
# participant_type
# case                   NaN       2.0       2.0       3.0       2.0       5.0
# control                1.0       1.0       4.0       1.0       2.0       3.0
#
# agegroup          85+
# participant_type
# case              1.0
# control           1.0
#
#
# Leeds Teaching Hospitals NHS Trust (16)
# -----------------
# 41 enrolled in 820 days (40 cases, 1 controls) - 0.35/week
# 39 in -29 days to go - -9.41/week
#
#
# agegroup          50 to 54  60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  \
# participant_type
# case                   1.0       2.0       7.0       8.0       9.0       8.0
# control                NaN       1.0       NaN       NaN       NaN       NaN
#
# agegroup          85+
# participant_type
# case              5.0
# control           NaN
#
#
# Portsmouth Hospitals NHS Trust (17)
# -----------------
# 12 enrolled in 820 days (6 cases, 6 controls) - 0.10/week
# 68 in -29 days to go - -16.41/week
#
#
# agegroup          75 to 79  80 to 84  85+
# participant_type
# case                   1.0       3.0  2.0
# control                4.0       2.0  NaN
#
#
# University Hospitals Birmingham NHS Foundation Trust (18)
# -----------------
# 16 enrolled in 820 days (15 cases, 1 controls) - 0.14/week
# 64 in -29 days to go - -15.45/week
#
#
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  80 to 84
# participant_type
# case                   NaN       5.0       3.0       6.0       1.0
# control                1.0       NaN       NaN       NaN       NaN
#
#
# Worcestershire Acute Hospitals NHS Trust (19)
# -----------------
# 14 enrolled in 820 days (7 cases, 7 controls) - 0.12/week
# 66 in -29 days to go - -15.93/week
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  85+
# participant_type
# case                   NaN       1.0       1.0       2.0  3.0
# control                2.0       NaN       3.0       1.0  1.0
#
#
# Guys’ and St Thomas’ NHS Foundation Trust (20)
# -----------------
# 55 enrolled in 820 days (31 cases, 24 controls) - 0.47/week
# 25 in -29 days to go - -6.03/week
#
#
# agegroup          60 to 64  65 to 69  70 to 74  75 to 79  80 to 84  85+
# participant_type
# case                     3         5         5        10         4    4
# control                  3         4         9         6         1    1
#
#
# Norfolk and Norwich University Hospitals NHS Foundation Trust (21)
# -----------------
# 9 enrolled in 820 days (7 cases, 2 controls) - 0.08/week
# 71 in -29 days to go - -17.14/week
#
#
# agegroup          55 to 59  60 to 64  70 to 74  80 to 84  85+
# participant_type
# case                   NaN       2.0       2.0       1.0  2.0
# control                2.0       NaN       NaN       NaN  NaN

# %%
df['tenyear-agegroup'] = pd.cut(df.years,
     ...:                    bins=[0, 25, 34, 44, 54, 64, 74, 999],
     ...:                    labels=['Under 25', '25-34', '35-44', '45-54', '55-64', '65-74', '75+'],
     ...:                    include_lowest=True) # do 10 year binning

# %%
for centre in ['05', '06', '07', '21', '10', '14', '15', '11']:
    try:
        print('{} ({})'.format(centre_lookup.get(int(centre)), centre))
        print('-----------------')
        print('\n')
        print(df[df.centre == centre].groupby('participant_type')['tenyear-agegroup'].value_counts(sort=False).unstack())
        print('\n')   
    except IndexError:
        continue
# Out:
# University Hospital of South Manchester (05)
# -----------------
#
#
# tenyear-agegroup  55-64  65-74  75+
# participant_type
# case                  4     17   19
# control               5     14   13
#
#
# Papworth Hospital NHS Foundation Trust (06)
# -----------------
#
#
# tenyear-agegroup  35-44  55-64  65-74   75+
# participant_type
# case                NaN    3.0   14.0  18.0
# control             1.0    5.0   15.0  15.0
#
#
# Royal Devon and Exeter NHS Foundation Trust (07)
# -----------------
#
#
# tenyear-agegroup  35-44  45-54  55-64  65-74  75+
# participant_type
# case                NaN    NaN    3.0    4.0  8.0
# control             1.0    1.0    2.0    4.0  7.0
#
#
# Norfolk and Norwich University Hospitals NHS Foundation Trust (21)
# -----------------
#
#
# tenyear-agegroup  55-64  65-74  75+
# participant_type
# case                2.0    2.0  3.0
# control             2.0    NaN  NaN
#
#
# Imperial College Healthcare NHS Trust (10)
# -----------------
#
#
# tenyear-agegroup  25-34  45-54  55-64  65-74   75+
# participant_type
# case                NaN    NaN    NaN    5.0  16.0
# control             1.0    3.0    7.0   33.0  25.0
#
#
# The Newcastle Upon Tyne Hospitals NHS Foundation Trust (14)
# -----------------
#
#
# tenyear-agegroup  55-64  65-74   75+
# participant_type
# case                1.0    7.0  12.0
# control             NaN    9.0   7.0
#
#
# Taunton and Somerset NHS Foundation Trust (15)
# -----------------
#
#
# tenyear-agegroup  55-64  65-74  75+
# participant_type
# case                  2      5    8
# control               2      5    6
#
#
# Aberdeen Royal Infirmary (11)
# -----------------
#
#
# tenyear-agegroup  45-54  55-64  65-74  75+
# participant_type
# case                2.0    2.0    5.0  3.0
# control             NaN    2.0    4.0  3.0

# %%
cake = psql.read_sql("SELECT * FROM ipfjes_demographics", conn)

# %%
cake = cake[cake.hospital_number.str[:2] == '01']

# %% [markdown]
# ##### set(cake.patient_id) - set(jam.episode_id)

# %%
df.head()
# Out:
#     id created_x                         updated_x consistency_token_x  \
# 0   95      None  2017-10-10 13:21:47.570745+01:00            6ff1370e
# 1   30      None  2018-07-05 14:05:28.384524+01:00            4048aec2
# 2  429      None  2018-05-14 11:29:00.482781+01:00            4bebff27
# 3   37      None  2017-08-09 12:04:15.256730+01:00            091c2bdc
# 4  523      None  2018-07-12 08:49:38.331069+01:00            c78b85d8
#
#   hospital_number nhs_number     surname first_name middle_name date_of_birth  \
# 0          020007       None      Falvey      Brian        None    1936-10-17
# 1          080016       None  Gilbertson      Peter        None    1939-12-05
# 2          090041       None      Sevier      David        None    1941-12-24
# 3          010002       None       Davis       Tony        None    1942-11-24
# 4          060003       None     Chapman    Kenneth        None    1943-08-12
#
#         ...        site_fk_id updated_by_id_y comments  \
# 0       ...              12.0               3
# 1       ...               2.0               3
# 2       ...               9.0               3
# 3       ...               4.0               3
# 4       ...               7.0               1
#
#                  email_address                                 postal_address  \
# 0  brain.falvey@btinternet.com
# 1     petergilbertson@manx.net
# 2                         None  89 Neville Road, Kingswood. Bristol. BS15 1XX
# 3            judytonyd@msn.com
# 4                         None     208 Southfields Ave, Peterborough, PE2 8RY
#
#   want_updates centre years  agegroup tenyear-agegroup
# 0          Yes     02    82  80 to 84              75+
# 1          Yes     08    79  75 to 79              75+
# 2          Yes     09    77  75 to 79              75+
# 3          Yes     01    76  75 to 79              75+
# 4          Yes     06    76  75 to 79              75+
#
# [5 rows x 47 columns]

# %%
df[df.centre == centre].groupby('participant_type').agegroup.value_counts(sort=False)
# Out:
# participant_type  agegroup
# case              50 to 54    2
#                   60 to 64    2
#                   65 to 69    3
#                   70 to 74    2
#                   75 to 79    2
#                   85+         1
# control           55 to 59    2
#                   65 to 69    2
#                   70 to 74    2
#                   75 to 79    1
#                   80 to 84    1
#                   85+         1
# Name: agegroup, dtype: int64

# %%
print(df.groupby('participant_type').agegroup.value_counts(sort=False).unstack())
# Out:
# agegroup          30 to 34  35 to 39  40 to 44  50 to 54  55 to 59  60 to 64  \
# participant_type
# case                   NaN       NaN       NaN       4.0      10.0      32.0
# control                1.0       1.0       1.0       5.0      13.0      41.0
#
# agegroup          65 to 69  70 to 74  75 to 79  80 to 84   85+
# participant_type
# case                  61.0     104.0     130.0      92.0  64.0
# control               66.0     113.0     102.0      64.0  40.0

# %%
df.columns
# Out:
# Index(['id', 'created_x', 'updated_x', 'consistency_token_x',
#        'hospital_number', 'nhs_number', 'surname', 'first_name', 'middle_name',
#        'date_of_birth', 'religion', 'date_of_death', 'post_code',
#        'gp_practice_code', 'death_indicator', 'title_ft', 'marital_status_ft',
#        'sex_ft', 'birth_place_ft', 'ethnicity_ft', 'birth_place_fk_id',
#        'created_by_id_x', 'ethnicity_fk_id', 'marital_status_fk_id',
#        'patient_id', 'sex_fk_id', 'title_fk_id', 'updated_by_id_x',
#        'contact_details', 'phone_number', 'created_y', 'updated_y',
#        'consistency_token_y', 'participant_type', 'site_ft', 'created_by_id_y',
#        'episode_id', 'site_fk_id', 'updated_by_id_y', 'comments',
#        'email_address', 'postal_address', 'want_updates', 'centre', 'years',
#        'agegroup', 'tenyear-agegroup'],
#       dtype='object')

# %%
df[(df.centre == '10') & (df.agegroup == '75 to 79')][['participant_type', 'hospital_number']]
# Out:
#     participant_type hospital_number
# 198             case          100017
# 221             case          100016
# 252             case          100019
# 336             case          100023
# 436             case          100003
# 775          control          100098
# 835          control          100034
# 849          control          100040
# 856          control          100041
# 858          control          100043
# 888          control          100030
# 903          control          100044
# 907          control          100045
# 914          control          100049
# 920          control          100050
# 922          control          100052
# 943          control          100061
# 956          control          100068
# 994          control          100091
# 995          control          100092
