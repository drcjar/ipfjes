# %%
import xlrd
import pandas as pd

# %%
df = pd.read_excel('../data/soc2000index_tcm77-179123.xls', sheetname=1 ) 
http://webarchive.nationalarchives.gov.uk/20160105160709/http://www.ons.gov.uk/ons/guide-method/classifications/archived-standard-classifications/standard-occupational-classification-2000/dissemination-media-and-availability/soc2000-index.xls

# %%
df[df.SOC == '541']
# Out:
#        RECNO    D  NEW    E  SOC SOC2000                  INDEXOCC  \
# 2497    2498  NaN  NaN  NaN  541    5232                    Beader
# 3091    3092  NaN  NaN  NaN  541    5232        Builder, ambulance
# 3099    3100  NaN  NaN  NaN  541    5232             Builder, body
# 3102    3103  NaN  NaN  NaN  541    5232          Builder, caravan
# 3103    3104  NaN  NaN  NaN  541    5232         Builder, carriage
# 3107    3108  NaN  NaN  NaN  541    5232            Builder, coach
# 3119    3120  NaN  NaN  NaN  541    5232            Builder, frame
# 3157    3158  NaN  NaN  NaN  541    5232          Builder, vehicle
# 3158    3159  NaN  NaN  NaN  541    5232            Builder, wagon
# 8455    8456  NaN  NaN  NaN  541    5232            Finisher, body
# 8466    8467  NaN  NaN  NaN  541    5232             Finisher, car
# 8476    8477  NaN  NaN  NaN  541    5232           Finisher, coach
# 8594    8595  NaN  NaN  NaN  541    5232                  Finisher
# ...
