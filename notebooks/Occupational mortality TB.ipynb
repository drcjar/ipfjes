# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Men16_64.csv')
# Occupational mortality in England and Wales, 1991-2000 - Men age 16-64
# from http://webarchive.nationalarchives.gov.uk/20150907090421/http://www.ons.gov.uk/ons/publications/re-reference-tables.html?edition=tcm%3A77-168405

df1 = pd.read_csv('../data/Men16_64_2.csv')
# Occupational mortality in England and Wales, 2000-2010 - Men age 16-64
# https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/healthandsocialcare/healthinequalities/adhocs/007958occupationalmortalityinenglandandwales2001to2010/mrp25652012pmrs200110.xls

# %%
df.columns = ['diagrp', 'Cause', 'SOdm', 'Occupation', 'Observed', 'Exp_Adj',
       'PMR_Adj', 'Lower_Adj', 'Upper_Adj', 'Exp_Unadj', 'PMR_Unadj',
       'Lower_Unadj', 'Upper_Unadj']

# remove trailing space from 'Cause' in

# %% [markdown]
# # TB occupational mortality in England and Wales, 1991-2000 - Men age 16-64

# %%
df[df['Cause'] == 'Tuberculosis'].sort_values(by='PMR_Adj', ascending=False)
# Out:
#      diagrp         Cause  SOdm  \
# 249       2  Tuberculosis    69
# 306       2  Tuberculosis   135
# 320       2  Tuberculosis   151
# 231       2  Tuberculosis    51
# 223       2  Tuberculosis    43
# 254       2  Tuberculosis    74
# 252       2  Tuberculosis    72
# 248       2  Tuberculosis    68
# 194       2  Tuberculosis    14
# 340       2  Tuberculosis   177
# 291       2  Tuberculosis   117
# 195       2  Tuberculosis    15
# 251       2  Tuberculosis    71
# 216       2  Tuberculosis    36
# 339       2  Tuberculosis   176
# 330       2  Tuberculosis   167
# 181       2  Tuberculosis     1
# 239       2  Tuberculosis    59
# 187       2  Tuberculosis     7
# 286       2  Tuberculosis   112
# 273       2  Tuberculosis    98
# 226       2  Tuberculosis    46
# 213       2  Tuberculosis    33
# 269       2  Tuberculosis    93
# 275       2  Tuberculosis   100
# 293       2  Tuberculosis   120
# 232       2  Tuberculosis    52
# 257       2  Tuberculosis    77
# ...

# %%
df[(df['Cause'] == 'Tuberculosis') & (df['Observed'] > 30)].sort_values(by='PMR_Adj', ascending=False)
# Out:
#      diagrp         Cause  SOdm            Occupation  Observed  Exp_Adj  \
# 189       2  Tuberculosis     9  Other Administrators        34    22.48
# 360       2  Tuberculosis   198       Other Labourers        63    59.15
#
#      PMR_Adj  Lower_Adj  Upper_Adj  Exp_Unadj  PMR_Unadj  Lower_Unadj  \
# 189    151.0      105.0      211.0      28.66      119.0         82.0
# 360    107.0       82.0      136.0      35.33      178.0        137.0
#
#      Upper_Unadj
# 189        166.0
# 360        228.0

# %%
df[(df['Cause'] == 'Tuberculosis') & (df['Lower_Adj'] > 90)].sort_values(by='PMR_Adj', ascending=False)
# Out:
#      diagrp         Cause  SOdm                          Occupation  Observed  \
# 249       2  Tuberculosis    69        Preparatory Fibre Processors         2
# 320       2  Tuberculosis   151                   Jewellery workers         2
# 231       2  Tuberculosis    51  Launderers, Dry Cleaners, Pressers         4
# 216       2  Tuberculosis    36                           Seafarers         9
# 239       2  Tuberculosis    59           Cooks and Kitchen Porters        15
# 226       2  Tuberculosis    46                            Caterers        11
# 324       2  Tuberculosis   160               Painters & Decorators        17
# 189       2  Tuberculosis     9                Other Administrators        34
#
#      Exp_Adj  PMR_Adj  Lower_Adj  Upper_Adj  Exp_Unadj  PMR_Unadj  \
# 249     0.12   1627.0      197.0     5879.0       0.11     1798.0
# 320     0.24    845.0      102.0     3053.0       0.27      741.0
# 231     0.71    567.0      154.0     1450.0       0.61      660.0
# ...

# %% [markdown]
# # TB occupational mortality in England and Wales, 2000-2010 - Men age 16-64

# %%
df1[df1['Cause'] == 'Tuberculosis'].sort_values(by='PMR_Adj', ascending=False)
# Out:
#      diagrp         Cause  jobcode  \
# 111       1  Tuberculosis     1510
# 14        1  Tuberculosis      150
# 101       1  Tuberculosis     1400
# 77        1  Tuberculosis      940
# 24        1  Tuberculosis      250
# 103       1  Tuberculosis     1420
# 7         1  Tuberculosis       80
# 13        1  Tuberculosis      140
# 62        1  Tuberculosis      631
# 80        1  Tuberculosis      980
# 68        1  Tuberculosis      750
# 96        1  Tuberculosis     1300
# 92        1  Tuberculosis     1200
# 31        1  Tuberculosis      320
# 63        1  Tuberculosis      640
# 45        1  Tuberculosis      460
# 87        1  Tuberculosis     1050
# 65        1  Tuberculosis      671
# 16        1  Tuberculosis      170
# 35        1  Tuberculosis      360
# 126       1  Tuberculosis     1760
# 43        1  Tuberculosis      440
# 138       1  Tuberculosis     1940
# 102       1  Tuberculosis     1410
# 32        1  Tuberculosis      330
# ...

# %%
df1[(df1['Cause'] == 'Tuberculosis') & (df1['Observed'] > 30)].sort_values(by='PMR_Adj', ascending=False)
# Out:
#      diagrp         Cause  jobcode                  Occupation  Observed  \
# 43        1  Tuberculosis      440       Retailers and Dealers        33
# 125       1  Tuberculosis     1740  Other Construction Workers        33
#
#      Exp_Adj  PMR_Adj  Lower_Adj  Upper_Adj  Exp_Unadj  PMR_Unadj  \
# 43     17.95    184.0      127.0      258.0      16.66      198.0
# 125    43.63     76.0       52.0      106.0      37.91       87.0
#
#      Lower_Unadj  Upper_Unadj
# 43         136.0        278.0
# 125         60.0        122.0

# %%
df1[(df1['Cause'] == 'Tuberculosis') & (df1['Lower_Adj'] > 90)].sort_values(by='PMR_Adj', ascending=False)
# Out:
#      diagrp         Cause  jobcode                                 Occupation  \
# 14        1  Tuberculosis      150                                    Doctors
# 103       1  Tuberculosis     1420  Other Electrical/Electronic Trades n.e.c.
# 45        1  Tuberculosis      460                                   Caterers
# 43        1  Tuberculosis      440                      Retailers and Dealers
#
#      Observed  Exp_Adj  PMR_Adj  Lower_Adj  Upper_Adj  Exp_Unadj  PMR_Unadj  \
# 14          7     1.12    626.0      251.0     1290.0       1.59      441.0
# 103         4     1.08    371.0      101.0      950.0       1.49      268.0
# 45         12     5.51    218.0      113.0      380.0       4.91      245.0
# 43         33    17.95    184.0      127.0      258.0      16.66      198.0
#
#      Lower_Unadj  Upper_Unadj
# 14         177.0        908.0
# 103         73.0        686.0
# 45         126.0        427.0
# 43         136.0        278.0
