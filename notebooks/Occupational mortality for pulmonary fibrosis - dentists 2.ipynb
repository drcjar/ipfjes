# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Men65_74_2.csv')
# Occupational mortality in England and Wales, 2000-2010 - Men age 65-74

# %%
df[(df['Occupation'] == 'Dental Technicians') & (df['Cause'] == 'Pulmonary fibrosis')]
# Out:
# Empty DataFrame
# Columns: [Cause, jobcode, Occupation, Observed, Exp_Adj, PMR_Adj, Lower_Adj, Upper_Adj]
# Index: []

# %%
df[(df['Occupation'] == 'Dentists') & (df['Cause'] == 'Pulmonary fibrosis')]
# Out:
#                  Cause  jobcode Occupation  Observed  Exp_Adj  PMR_Adj  \
# 15  Pulmonary fibrosis      160   Dentists         5     3.54      141
#
#     Lower_Adj  Upper_Adj
# 15         46        330

# %%
df[df['Cause'] == 'Pulmonary fibrosis'].sort_values(by='PMR_Adj', ascending=False)
# Out:
#                   Cause  jobcode  \
# 139  Pulmonary fibrosis     1950
# 59   Pulmonary fibrosis      601
# 61   Pulmonary fibrosis      620
# 21   Pulmonary fibrosis      220
# 63   Pulmonary fibrosis      640
# 19   Pulmonary fibrosis      200
# 90   Pulmonary fibrosis     1160
# 71   Pulmonary fibrosis      791
# 49   Pulmonary fibrosis      500
# 138  Pulmonary fibrosis     1940
# 51   Pulmonary fibrosis      520
# 92   Pulmonary fibrosis     1200
# 80   Pulmonary fibrosis      980
# 91   Pulmonary fibrosis     1170
# 41   Pulmonary fibrosis      420
# 111  Pulmonary fibrosis     1510
# 67   Pulmonary fibrosis      740
# 103  Pulmonary fibrosis     1420
# 15   Pulmonary fibrosis      160
# 73   Pulmonary fibrosis      821
# 114  Pulmonary fibrosis     1580
# 82   Pulmonary fibrosis     1000
# 11   Pulmonary fibrosis      120
# 107  Pulmonary fibrosis     1460
# 113  Pulmonary fibrosis     1540
# 0    Pulmonary fibrosis       10
# 2    Pulmonary fibrosis       30
# ...
