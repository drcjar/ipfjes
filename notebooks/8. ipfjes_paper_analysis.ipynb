# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
# %matplotlib inline
from scipy.stats import scoreatpercentile
import math
import numpy as np

pd.options.display.float_format = '{:,.2f}'.format

import scipy.stats as stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# jobs_dataframe.csv
# job_tasks_dataframe.csv
# flat_dataframe.csv

# %%
df = pd.read_csv('flat_dataframe.csv')
reorderjobcat = {1.:5 , 2.2:4, 3.:3 , 2.1:4, 2.3:4, 5.:1 , 4.:2}
df['lowest_peto_cat_reordered'] = df.lowest_peto_cat.map(reorderjobcat) # make it so highest n is highest exposed
df['median_ssec_int'] = df.median_ssec.astype(int)

df.to_csv('flat_data_sans_genotype.csv', index=False)

# %% [markdown]
# # table one

# %%
df.groupby('case').age.describe()
# Out:
#       count  mean  std   min   25%   50%   75%   max
# case
# 0    466.00 74.43 8.52 34.00 69.00 75.00 80.00 95.00
# 1    494.00 76.59 7.84 53.00 72.00 77.00 82.00 95.00

# %%
print(df.groupby('case').ethnicity.value_counts() )
print(df.groupby('case').ethnicity.value_counts(normalize=True) )
# Out:
# case  ethnicity
# 0     White                                        449
#       Asian / Asian British                          8
#       Black / African/ Caribbean/ Black British      7
#       Other ethnic group                             2
# 1     White                                        479
#       Asian / Asian British                         11
#       Black / African/ Caribbean/ Black British      2
#       Arab                                           1
#       Mixed / Multiple ethnic groups                 1
# Name: ethnicity, dtype: int64
# case  ethnicity
# 0     White                                       0.96
#       Asian / Asian British                       0.02
#       Black / African/ Caribbean/ Black British   0.02
#       Other ethnic group                          0.00
# 1     White                                       0.97
#       Asian / Asian British                       0.02
#       Black / African/ Caribbean/ Black British   0.00
#       Arab                                        0.00
#       Mixed / Multiple ethnic groups              0.00
# Name: ethnicity, dtype: float64

# %%
print (df.groupby('case')['median_ssec_int'].value_counts(sort=False))
print (df.groupby('case')['median_ssec_int'].value_counts(sort=False,normalize=True))
# Out:
# case  median_ssec_int
# 0     1                   39
#       2                   60
#       3                   75
#       4                   52
#       5                   98
#       6                   89
#       7                   53
# 1     1                   38
#       2                   58
#       3                   73
#       4                   53
#       5                   94
#       6                  113
#       7                   65
# Name: median_ssec_int, dtype: int64
# case  median_ssec_int
# 0     1                 0.08
#       2                 0.13
#       3                 0.16
#       4                 0.11
#       5                 0.21
#       6                 0.19
#       7                 0.11
# 1     1                 0.08
#       2                 0.12
#       3                 0.15
#       4                 0.11
#       5                 0.19
#       6                 0.23
#       7                 0.13
# Name: median_ssec_int, dtype: float64

# %%
print (df.groupby('case')['current_smoker'].value_counts(sort=False))
print (df.groupby('case')['current_smoker'].value_counts(sort=False,normalize=True))
# Out:
# case  current_smoker
# 0     0                 436
#       1                  30
# 1     0                 484
#       1                  10
# Name: current_smoker, dtype: int64
# case  current_smoker
# 0     0                0.94
#       1                0.06
# 1     0                0.98
#       1                0.02
# Name: current_smoker, dtype: float64

# %%
print (df.groupby('case')['ever_smoked'].value_counts(sort=False))
print (df.groupby('case')['ever_smoked'].value_counts(sort=False, normalize=True))
# Out:
# case  ever_smoked
# 0     0              139
#       1              327
# 1     0              121
#       1              373
# Name: ever_smoked, dtype: int64
# case  ever_smoked
# 0     0             0.30
#       1             0.70
# 1     0             0.24
#       1             0.76
# Name: ever_smoked, dtype: float64

# %%
df[df['packyrs'] > 0].groupby('case')['packyrs'].describe()
# Out:
#       count  mean   std  min   25%   50%   75%    max
# case
# 0    301.00 26.16 24.94 1.00  9.00 21.00 36.00 165.00
# 1    350.00 27.60 26.03 1.00 10.25 21.00 37.75 220.00

# %%
print (df.groupby('case')['mrc_score'].value_counts(sort=False))
print (df.groupby('case')['mrc_score'].value_counts(sort=False, normalize=True))
# Out:
# case  mrc_score
# 0     0.00         254
#       1.00          65
#       2.00          80
#       3.00          65
#       4.00           2
# 1     0.00          35
#       1.00          94
#       2.00         165
#       3.00         172
#       4.00          28
# Name: mrc_score, dtype: int64
# case  mrc_score
# 0     0.00        0.55
#       1.00        0.14
#       2.00        0.17
#       3.00        0.14
#       4.00        0.00
# 1     0.00        0.07
#       1.00        0.19
#       2.00        0.33
#       3.00        0.35
#       4.00        0.06
# Name: mrc_score, dtype: float64

# %% [markdown]
# # table two

# %%
print(df.groupby('case').peto_exposed.value_counts(sort=False) )
print(df.groupby('case').peto_exposed.value_counts(sort=False,normalize=True) )
# Out:
# case  peto_exposed
# 0     0               174
#       1               292
# 1     0               168
#       1               326
# Name: peto_exposed, dtype: int64
# case  peto_exposed
# 0     0              0.37
#       1              0.63
# 1     0              0.34
#       1              0.66
# Name: peto_exposed, dtype: float64

# %%
print(df.groupby('case').lowest_peto_cat_reordered.value_counts(sort=False) )
print(df.groupby('case').lowest_peto_cat_reordered.value_counts(normalize=True,sort=False) )
# Out:
# case  lowest_peto_cat_reordered
# 0     1                             76
#       2                             98
#       3                            115
#       4                            126
#       5                             51
# 1     1                             74
#       2                             94
#       3                            124
#       4                            138
#       5                             64
# Name: lowest_peto_cat_reordered, dtype: int64
# case  lowest_peto_cat_reordered
# 0     1                           0.16
#       2                           0.21
#       3                           0.25
#       4                           0.27
#       5                           0.11
# 1     1                           0.15
#       2                           0.19
#       3                           0.25
#       4                           0.28
#       5                           0.13
# Name: lowest_peto_cat_reordered, dtype: float64

# %%
print(df[df.fibre_ml_exposure > 0].groupby('case').fibre_ml_exposure.describe())
print(df[df.fibre_ml_exposure >= 100].groupby('case').fibre_ml_exposure.describe())
print(df[df.fibre_ml_exposure >= 50].groupby('case').fibre_ml_exposure.describe())
print(df[df.fibre_ml_exposure >= 25].groupby('case').fibre_ml_exposure.describe())
# Out:
#       count     mean      std  min  25%  50%   75%       max
# case
# 0    107.00   623.09 3,092.38 0.00 0.21 4.76 59.93 23,785.71
# 1    122.00 1,117.93 5,641.48 0.00 0.30 5.86 62.98 50,761.90
#       count     mean       std    min    25%    50%      75%       max
# case
# 0     24.00 2,743.04  6,166.46 105.21 216.02 466.14 1,182.85 23,785.71
# 1     27.00 5,013.71 11,308.10 102.74 187.29 594.64 3,615.46 50,761.90
#       count     mean       std   min    25%    50%      75%       max
# case
# 0     29.00 2,281.78  5,682.68 52.86 144.00 290.83 1,126.29 23,785.71
# 1     34.00 3,995.43 10,240.56 55.15 121.27 297.05 3,214.13 50,761.90
#       count     mean      std   min   25%    50%      75%       max
# case
# 0     35.00 1,896.92 5,227.91 27.12 66.32 222.00 1,067.43 23,785.71
# 1     40.00 3,401.64 9,528.10 28.81 68.42 187.29 1,660.67 50,761.90

# %%
print(df[df.fibre_ml_exposure > 0].groupby('case').fibre_ml_exposure.describe())
print(df[(df.fibre_ml_exposure > 0) & (df.fibre_ml_exposure < 5)].groupby('case').fibre_ml_exposure.describe())
print(df[(df.fibre_ml_exposure >= 5) & (df.fibre_ml_exposure < 10)].groupby('case').fibre_ml_exposure.describe())
print(df[(df.fibre_ml_exposure >= 10) & (df.fibre_ml_exposure < 15)].groupby('case').fibre_ml_exposure.describe())
print(df[(df.fibre_ml_exposure >= 15) & (df.fibre_ml_exposure < 20)].groupby('case').fibre_ml_exposure.describe())
print(df[(df.fibre_ml_exposure >= 20) & (df.fibre_ml_exposure < 25)].groupby('case').fibre_ml_exposure.describe())
print(df[df.fibre_ml_exposure >= 25].groupby('case').fibre_ml_exposure.describe())
# Out:
#       count     mean      std  min  25%  50%   75%       max
# case
# 0    107.00   623.09 3,092.38 0.00 0.21 4.76 59.93 23,785.71
# 1    122.00 1,117.93 5,641.48 0.00 0.30 5.86 62.98 50,761.90
#       count  mean  std  min  25%  50%  75%  max
# case
# 0     55.00  0.77 1.22 0.00 0.03 0.23 0.84 4.83
# 1     61.00  0.98 1.39 0.00 0.04 0.28 1.11 4.86
#       count  mean  std  min  25%  50%  75%  max
# case
# 0      4.00  7.08 1.18 5.68 6.54 7.04 7.57 8.55
# 1     10.00  7.98 1.08 6.86 7.06 7.72 8.91 9.82
#       count  mean  std   min   25%   50%   75%   max
# case
# 0      8.00 12.44 1.51 10.52 11.38 12.29 13.44 14.75
# 1      5.00 12.13 0.89 10.87 11.77 12.05 12.79 13.15
#       count  mean  std   min   25%   50%   75%   max
# case
# 1      2.00 15.79 0.77 15.25 15.52 15.79 16.07 16.34
#       count  mean  std   min   25%   50%   75%   max
# case
# 0      5.00 21.73 1.81 20.27 21.03 21.04 21.43 24.89
# 1      4.00 22.69 1.39 20.83 22.04 23.03 23.69 23.88
#       count     mean      std   min   25%    50%      75%       max
# case
# 0     35.00 1,896.92 5,227.91 27.12 66.32 222.00 1,067.43 23,785.71
# 1     40.00 3,401.64 9,528.10 28.81 68.42 187.29 1,660.67 50,761.90

# %% [markdown]
# # table three

# %%
model = smf.logit('case ~ peto_exposed', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.692118
#          Iterations 3
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      958
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:               0.0008721
# Time:                        23:26:57   Log-Likelihood:                -664.43
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                    0.2815
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0351      0.108     -0.324      0.746      -0.247       0.177
# peto_exposed     0.1452      0.135      1.077      0.282      -0.119       0.410
# ================================================================================
# Odds Ratios
# ======================
#               2.5%  97.5%   OR
# Intercept     0.78   1.19 0.97
# peto_exposed  0.89   1.51 1.16

# %%
model = smf.logit('case ~ age + ever_smoked + C(centre_name) + peto_exposed', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.631342
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      936
# Method:                           MLE   Df Model:                           23
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.08861
# Time:                        23:26:57   Log-Likelihood:                -606.09
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                 1.013e-14
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                          -3.2135      0.785     -4.091      0.000      -4.753      -1.674
# C(centre_name)[T.Aintree University Hospitals NHS Foundation Trust]                -0.2533      0.496     -0.511      0.610      -1.226       0.719
# C(centre_name)[T.Glasgow Royal Infirmary]                                           0.3532      0.894      0.395      0.693      -1.399       2.105
# C(centre_name)[T.Guys’ and St Thomas’ NHS Foundation Trust]                        -0.0099      0.516     -0.019      0.985      -1.022       1.002
# C(centre_name)[T.Heart of England NHS Foundation Trust]                            -0.1461      0.494     -0.296      0.767      -1.114       0.821
# C(centre_name)[T.Imperial College Healthcare NHS Trust]                            -1.4604      0.506     -2.886      0.004      -2.452      -0.468
# C(centre_name)[T.Leeds Teaching Hospitals NHS Trust]                                2.7892      0.849      3.286      0.001       1.126       4.453
# C(centre_name)[T.Morriston Hospital]                                               -0.0206      0.605     -0.034      0.973      -1.206       1.165
# C(centre_name)[T.Norfolk and Norwich University Hospitals NHS Foundation Trust]     1.1722      0.925      1.267      0.205      -0.642       2.986
# C(centre_name)[T.North Bristol NHS Trust]                                          -0.2909      0.515     -0.565      0.572      -1.300       0.718
# C(centre_name)[T.Nottingham University Hospitals NHS Trust]                        -0.2235      0.500     -0.447      0.655      -1.204       0.757
# C(centre_name)[T.Papworth Hospital NHS Foundation Trust]                           -0.2166      0.500     -0.433      0.665      -1.197       0.764
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]                                   -0.4835      0.733     -0.660      0.510      -1.920       0.953
# C(centre_name)[T.Royal Devon and Exeter NHS Foundation Trust]                      -0.2237      0.574     -0.390      0.697      -1.349       0.901
# C(centre_name)[T.Royal Infirmary of Edinburgh]                                     -0.3011      0.587     -0.513      0.608      -1.452       0.849
# C(centre_name)[T.Southampton University Hospitals NHS Trust]                       -0.2827      0.485     -0.583      0.560      -1.233       0.668
# C(centre_name)[T.Taunton and Somerset NHS Foundation Trust]                        -0.1225      0.579     -0.212      0.832      -1.257       1.012
# C(centre_name)[T.The Newcastle Upon Tyne Hospitals NHS Foundation Trust]           -0.0061      0.555     -0.011      0.991      -1.094       1.082
# C(centre_name)[T.University Hospital of South Manchester]                           0.1252      0.501      0.250      0.803      -0.857       1.107
# C(centre_name)[T.University Hospitals Birmingham NHS Foundation Trust]              2.7515      1.126      2.443      0.015       0.544       4.959
# C(centre_name)[T.Worcestershire Acute Hospitals NHS Trust]                         -0.6521      0.678     -0.962      0.336      -1.981       0.677
# age                                                                                 0.0416      0.009      4.673      0.000       0.024       0.059
# ever_smoked                                                                         0.3319      0.158      2.102      0.036       0.022       0.641
# peto_exposed                                                                        0.0754      0.146      0.516      0.606      -0.211       0.361
# ===================================================================================================================================================
# Odds Ratios
# ======================
#                                                     2.5%  97.5%    OR
# Intercept                                           0.01   0.19  0.04
# C(centre_name)[T.Aintree University Hospitals N...  0.29   2.05  0.78
# C(centre_name)[T.Glasgow Royal Infirmary]           0.25   8.21  1.42
# C(centre_name)[T.Guys’ and St Thomas’ NHS Found...  0.36   2.72  0.99
# C(centre_name)[T.Heart of England NHS Foundatio...  0.33   2.27  0.86
# C(centre_name)[T.Imperial College Healthcare NH...  0.09   0.63  0.23
# C(centre_name)[T.Leeds Teaching Hospitals NHS T...  3.08  85.87 16.27
# C(centre_name)[T.Morriston Hospital]                0.30   3.21  0.98
# C(centre_name)[T.Norfolk and Norwich University...  0.53  19.80  3.23
# C(centre_name)[T.North Bristol NHS Trust]           0.27   2.05  0.75
# C(centre_name)[T.Nottingham University Hospital...  0.30   2.13  0.80
# C(centre_name)[T.Papworth Hospital NHS Foundati...  0.30   2.15  0.81
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]    0.15   2.59  0.62
# C(centre_name)[T.Royal Devon and Exeter NHS Fou...  0.26   2.46  0.80
# C(centre_name)[T.Royal Infirmary of Edinburgh]      0.23   2.34  0.74
# C(centre_name)[T.Southampton University Hospita...  0.29   1.95  0.75
# C(centre_name)[T.Taunton and Somerset NHS Found...  0.28   2.75  0.88
# C(centre_name)[T.The Newcastle Upon Tyne Hospit...  0.33   2.95  0.99
# C(centre_name)[T.University Hospital of South M...  0.42   3.03  1.13
# C(centre_name)[T.University Hospitals Birmingha...  1.72 142.50 15.67
# C(centre_name)[T.Worcestershire Acute Hospitals...  0.14   1.97  0.52
# age                                                 1.02   1.06  1.04
# ever_smoked                                         1.02   1.90  1.39
# peto_exposed                                        0.81   1.44  1.08

# %%
model = smf.logit('case ~ C(lowest_peto_cat_reordered)', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.691862
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      955
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.001241
# Time:                        23:26:57   Log-Likelihood:                -664.19
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                    0.7997
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.0267      0.163     -0.163      0.870      -0.347       0.293
# C(lowest_peto_cat_reordered)[T.2]    -0.0150      0.218     -0.069      0.945      -0.442       0.412
# C(lowest_peto_cat_reordered)[T.3]     0.1020      0.208      0.490      0.624      -0.306       0.510
# C(lowest_peto_cat_reordered)[T.4]     0.1176      0.205      0.575      0.565      -0.283       0.519
# C(lowest_peto_cat_reordered)[T.5]     0.2537      0.249      1.020      0.308      -0.234       0.741
# =====================================================================================================
# Odds Ratios
# ======================
#                                    2.5%  97.5%   OR
# Intercept                          0.71   1.34 0.97
# C(lowest_peto_cat_reordered)[T.2]  0.64   1.51 0.99
# C(lowest_peto_cat_reordered)[T.3]  0.74   1.67 1.11
# C(lowest_peto_cat_reordered)[T.4]  0.75   1.68 1.12
# C(lowest_peto_cat_reordered)[T.5]  0.79   2.10 1.29

# %%
model = smf.logit('case ~ age + ever_smoked + C(centre_name) + C(lowest_peto_cat_reordered)', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.630770
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      933
# Method:                           MLE   Df Model:                           26
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.08943
# Time:                        23:26:58   Log-Likelihood:                -605.54
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                 7.554e-14
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                          -3.1921      0.796     -4.012      0.000      -4.751      -1.633
# C(centre_name)[T.Aintree University Hospitals NHS Foundation Trust]                -0.2884      0.498     -0.579      0.563      -1.265       0.688
# C(centre_name)[T.Glasgow Royal Infirmary]                                           0.3391      0.894      0.380      0.704      -1.412       2.090
# C(centre_name)[T.Guys’ and St Thomas’ NHS Foundation Trust]                        -0.0426      0.518     -0.082      0.934      -1.057       0.972
# C(centre_name)[T.Heart of England NHS Foundation Trust]                            -0.1694      0.495     -0.342      0.732      -1.140       0.802
# C(centre_name)[T.Imperial College Healthcare NHS Trust]                            -1.5019      0.509     -2.952      0.003      -2.499      -0.505
# C(centre_name)[T.Leeds Teaching Hospitals NHS Trust]                                2.7736      0.849      3.267      0.001       1.110       4.438
# C(centre_name)[T.Morriston Hospital]                                               -0.0224      0.605     -0.037      0.971      -1.208       1.164
# C(centre_name)[T.Norfolk and Norwich University Hospitals NHS Foundation Trust]     1.1803      0.929      1.271      0.204      -0.640       3.000
# C(centre_name)[T.North Bristol NHS Trust]                                          -0.3195      0.516     -0.619      0.536      -1.331       0.692
# C(centre_name)[T.Nottingham University Hospitals NHS Trust]                        -0.2430      0.502     -0.484      0.628      -1.227       0.741
# C(centre_name)[T.Papworth Hospital NHS Foundation Trust]                           -0.2318      0.501     -0.462      0.644      -1.215       0.751
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]                                   -0.5359      0.735     -0.729      0.466      -1.976       0.904
# C(centre_name)[T.Royal Devon and Exeter NHS Foundation Trust]                      -0.2418      0.575     -0.420      0.674      -1.370       0.886
# C(centre_name)[T.Royal Infirmary of Edinburgh]                                     -0.3276      0.588     -0.557      0.578      -1.481       0.826
# C(centre_name)[T.Southampton University Hospitals NHS Trust]                       -0.2998      0.486     -0.617      0.537      -1.252       0.652
# C(centre_name)[T.Taunton and Somerset NHS Foundation Trust]                        -0.1459      0.580     -0.252      0.801      -1.283       0.991
# C(centre_name)[T.The Newcastle Upon Tyne Hospitals NHS Foundation Trust]           -0.0413      0.556     -0.074      0.941      -1.132       1.049
# C(centre_name)[T.University Hospital of South Manchester]                           0.0907      0.503      0.180      0.857      -0.895       1.076
# C(centre_name)[T.University Hospitals Birmingham NHS Foundation Trust]              2.7474      1.127      2.438      0.015       0.539       4.956
# C(centre_name)[T.Worcestershire Acute Hospitals NHS Trust]                         -0.6543      0.680     -0.962      0.336      -1.987       0.679
# C(lowest_peto_cat_reordered)[T.2]                                                  -0.1637      0.235     -0.696      0.487      -0.625       0.298
# C(lowest_peto_cat_reordered)[T.3]                                                  -0.0654      0.227     -0.289      0.773      -0.509       0.379
# C(lowest_peto_cat_reordered)[T.4]                                                   0.0607      0.222      0.274      0.784      -0.374       0.495
# C(lowest_peto_cat_reordered)[T.5]                                                  -0.0960      0.269     -0.357      0.721      -0.623       0.431
# age                                                                                 0.0429      0.009      4.743      0.000       0.025       0.061
# ever_smoked                                                                         0.3333      0.158      2.104      0.035       0.023       0.644
# ===================================================================================================================================================
# Odds Ratios
# ======================
#                                                     2.5%  97.5%    OR
# Intercept                                           0.01   0.20  0.04
# C(centre_name)[T.Aintree University Hospitals N...  0.28   1.99  0.75
# C(centre_name)[T.Glasgow Royal Infirmary]           0.24   8.09  1.40
# C(centre_name)[T.Guys’ and St Thomas’ NHS Found...  0.35   2.64  0.96
# C(centre_name)[T.Heart of England NHS Foundatio...  0.32   2.23  0.84
# C(centre_name)[T.Imperial College Healthcare NH...  0.08   0.60  0.22
# C(centre_name)[T.Leeds Teaching Hospitals NHS T...  3.03  84.58 16.02
# C(centre_name)[T.Morriston Hospital]                0.30   3.20  0.98
# C(centre_name)[T.Norfolk and Norwich University...  0.53  20.09  3.26
# C(centre_name)[T.North Bristol NHS Trust]           0.26   2.00  0.73
# C(centre_name)[T.Nottingham University Hospital...  0.29   2.10  0.78
# C(centre_name)[T.Papworth Hospital NHS Foundati...  0.30   2.12  0.79
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]    0.14   2.47  0.59
# C(centre_name)[T.Royal Devon and Exeter NHS Fou...  0.25   2.43  0.79
# C(centre_name)[T.Royal Infirmary of Edinburgh]      0.23   2.28  0.72
# C(centre_name)[T.Southampton University Hospita...  0.29   1.92  0.74
# C(centre_name)[T.Taunton and Somerset NHS Found...  0.28   2.69  0.86
# C(centre_name)[T.The Newcastle Upon Tyne Hospit...  0.32   2.86  0.96
# C(centre_name)[T.University Hospital of South M...  0.41   2.93  1.09
# C(centre_name)[T.University Hospitals Birmingha...  1.71 142.05 15.60
# C(centre_name)[T.Worcestershire Acute Hospitals...  0.14   1.97  0.52
# C(lowest_peto_cat_reordered)[T.2]                   0.54   1.35  0.85
# C(lowest_peto_cat_reordered)[T.3]                   0.60   1.46  0.94
# C(lowest_peto_cat_reordered)[T.4]                   0.69   1.64  1.06
# C(lowest_peto_cat_reordered)[T.5]                   0.54   1.54  0.91
# age                                                 1.03   1.06  1.04
# ever_smoked                                         1.02   1.90  1.40

# %%
model = smf.logit('case ~ ever_smoked', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.690922
#          Iterations 3
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      958
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.002598
# Time:                        23:26:58   Log-Likelihood:                -663.29
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                   0.06305
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.1387      0.124     -1.115      0.265      -0.382       0.105
# ever_smoked     0.2703      0.146      1.857      0.063      -0.015       0.556
# ===============================================================================
# Odds Ratios
# ======================
#              2.5%  97.5%   OR
# Intercept    0.68   1.11 0.87
# ever_smoked  0.99   1.74 1.31

# %%
model = smf.logit('case ~ age + ever_smoked + C(centre_name)', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.631481
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      937
# Method:                           MLE   Df Model:                           22
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.08841
# Time:                        23:26:58   Log-Likelihood:                -606.22
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                 4.786e-15
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                          -3.1676      0.779     -4.064      0.000      -4.695      -1.640
# C(centre_name)[T.Aintree University Hospitals NHS Foundation Trust]                -0.2400      0.495     -0.485      0.628      -1.210       0.730
# C(centre_name)[T.Glasgow Royal Infirmary]                                           0.3385      0.893      0.379      0.705      -1.413       2.090
# C(centre_name)[T.Guys’ and St Thomas’ NHS Foundation Trust]                        -0.0126      0.516     -0.024      0.981      -1.023       0.998
# C(centre_name)[T.Heart of England NHS Foundation Trust]                            -0.1358      0.493     -0.276      0.783      -1.102       0.830
# C(centre_name)[T.Imperial College Healthcare NHS Trust]                            -1.4632      0.506     -2.894      0.004      -2.454      -0.472
# C(centre_name)[T.Leeds Teaching Hospitals NHS Trust]                                2.7912      0.848      3.290      0.001       1.128       4.454
# C(centre_name)[T.Morriston Hospital]                                               -0.0093      0.604     -0.015      0.988      -1.193       1.174
# C(centre_name)[T.Norfolk and Norwich University Hospitals NHS Foundation Trust]     1.2009      0.923      1.301      0.193      -0.609       3.011
# C(centre_name)[T.North Bristol NHS Trust]                                          -0.2887      0.514     -0.561      0.575      -1.297       0.719
# C(centre_name)[T.Nottingham University Hospitals NHS Trust]                        -0.2186      0.500     -0.437      0.662      -1.198       0.761
# C(centre_name)[T.Papworth Hospital NHS Foundation Trust]                           -0.2194      0.500     -0.439      0.661      -1.199       0.761
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]                                   -0.4712      0.733     -0.643      0.520      -1.907       0.965
# C(centre_name)[T.Royal Devon and Exeter NHS Foundation Trust]                      -0.2157      0.573     -0.376      0.707      -1.340       0.908
# C(centre_name)[T.Royal Infirmary of Edinburgh]                                     -0.2963      0.587     -0.505      0.614      -1.446       0.853
# C(centre_name)[T.Southampton University Hospitals NHS Trust]                       -0.2777      0.484     -0.573      0.566      -1.227       0.672
# C(centre_name)[T.Taunton and Somerset NHS Foundation Trust]                        -0.1171      0.578     -0.203      0.840      -1.250       1.016
# C(centre_name)[T.The Newcastle Upon Tyne Hospitals NHS Foundation Trust]            0.0017      0.554      0.003      0.998      -1.085       1.088
# C(centre_name)[T.University Hospital of South Manchester]                           0.1247      0.501      0.249      0.803      -0.856       1.106
# C(centre_name)[T.University Hospitals Birmingham NHS Foundation Trust]              2.7560      1.126      2.447      0.014       0.549       4.963
# C(centre_name)[T.Worcestershire Acute Hospitals NHS Trust]                         -0.6502      0.678     -0.960      0.337      -1.978       0.678
# age                                                                                 0.0415      0.009      4.666      0.000       0.024       0.059
# ever_smoked                                                                         0.3404      0.157      2.167      0.030       0.033       0.648
# ===================================================================================================================================================
# Odds Ratios
# ======================
#                                                     2.5%  97.5%    OR
# Intercept                                           0.01   0.19  0.04
# C(centre_name)[T.Aintree University Hospitals N...  0.30   2.08  0.79
# C(centre_name)[T.Glasgow Royal Infirmary]           0.24   8.08  1.40
# C(centre_name)[T.Guys’ and St Thomas’ NHS Found...  0.36   2.71  0.99
# C(centre_name)[T.Heart of England NHS Foundatio...  0.33   2.29  0.87
# C(centre_name)[T.Imperial College Healthcare NH...  0.09   0.62  0.23
# C(centre_name)[T.Leeds Teaching Hospitals NHS T...  3.09  85.98 16.30
# C(centre_name)[T.Morriston Hospital]                0.30   3.23  0.99
# C(centre_name)[T.Norfolk and Norwich University...  0.54  20.30  3.32
# C(centre_name)[T.North Bristol NHS Trust]           0.27   2.05  0.75
# C(centre_name)[T.Nottingham University Hospital...  0.30   2.14  0.80
# C(centre_name)[T.Papworth Hospital NHS Foundati...  0.30   2.14  0.80
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]    0.15   2.62  0.62
# C(centre_name)[T.Royal Devon and Exeter NHS Fou...  0.26   2.48  0.81
# C(centre_name)[T.Royal Infirmary of Edinburgh]      0.24   2.35  0.74
# C(centre_name)[T.Southampton University Hospita...  0.29   1.96  0.76
# C(centre_name)[T.Taunton and Somerset NHS Found...  0.29   2.76  0.89
# C(centre_name)[T.The Newcastle Upon Tyne Hospit...  0.34   2.97  1.00
# C(centre_name)[T.University Hospital of South M...  0.42   3.02  1.13
# C(centre_name)[T.University Hospitals Birmingha...  1.73 143.08 15.74
# C(centre_name)[T.Worcestershire Acute Hospitals...  0.14   1.97  0.52
# age                                                 1.02   1.06  1.04
# ever_smoked                                         1.03   1.91  1.41

# %%
model = smf.logit('case ~ ever_smoked*peto_exposed', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.688311
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      956
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.006367
# Time:                        23:26:58   Log-Likelihood:                -660.78
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                   0.03726
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.0339      0.184      0.184      0.854      -0.327       0.395
# ever_smoked                 -0.1054      0.228     -0.463      0.643      -0.551       0.341
# peto_exposed                -0.3175      0.250     -1.268      0.205      -0.808       0.173
# ever_smoked:peto_exposed     0.6168      0.298      2.067      0.039       0.032       1.202
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.72   1.48 1.03
# ever_smoked               0.58   1.41 0.90
# peto_exposed              0.45   1.19 0.73
# ever_smoked:peto_exposed  1.03   3.33 1.85

# %%
model = smf.logit('case ~ age + ever_smoked*peto_exposed + C(centre_name)', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.629552
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  960
# Model:                          Logit   Df Residuals:                      935
# Method:                           MLE   Df Model:                           24
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.09119
# Time:                        23:26:58   Log-Likelihood:                -604.37
# converged:                       True   LL-Null:                       -665.01
# Covariance Type:            nonrobust   LLR p-value:                 5.723e-15
# ===================================================================================================================================================
#                                                                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                          -3.0599      0.788     -3.884      0.000      -4.604      -1.516
# C(centre_name)[T.Aintree University Hospitals NHS Foundation Trust]                -0.2027      0.496     -0.408      0.683      -1.175       0.770
# C(centre_name)[T.Glasgow Royal Infirmary]                                           0.4877      0.901      0.541      0.588      -1.278       2.254
# C(centre_name)[T.Guys’ and St Thomas’ NHS Foundation Trust]                         0.0409      0.516      0.079      0.937      -0.971       1.053
# C(centre_name)[T.Heart of England NHS Foundation Trust]                            -0.0960      0.493     -0.195      0.846      -1.063       0.871
# C(centre_name)[T.Imperial College Healthcare NHS Trust]                            -1.4079      0.506     -2.784      0.005      -2.399      -0.417
# C(centre_name)[T.Leeds Teaching Hospitals NHS Trust]                                2.8116      0.848      3.314      0.001       1.149       4.474
# C(centre_name)[T.Morriston Hospital]                                                0.0100      0.603      0.017      0.987      -1.173       1.193
# C(centre_name)[T.Norfolk and Norwich University Hospitals NHS Foundation Trust]     1.1920      0.924      1.290      0.197      -0.619       3.003
# C(centre_name)[T.North Bristol NHS Trust]                                          -0.2549      0.515     -0.495      0.620      -1.264       0.754
# C(centre_name)[T.Nottingham University Hospitals NHS Trust]                        -0.1396      0.502     -0.278      0.781      -1.123       0.843
# C(centre_name)[T.Papworth Hospital NHS Foundation Trust]                           -0.1593      0.501     -0.318      0.750      -1.140       0.822
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]                                   -0.3877      0.736     -0.527      0.598      -1.830       1.054
# C(centre_name)[T.Royal Devon and Exeter NHS Foundation Trust]                      -0.1414      0.575     -0.246      0.806      -1.269       0.986
# C(centre_name)[T.Royal Infirmary of Edinburgh]                                     -0.2468      0.587     -0.421      0.674      -1.397       0.903
# C(centre_name)[T.Southampton University Hospitals NHS Trust]                       -0.2471      0.484     -0.510      0.610      -1.196       0.702
# C(centre_name)[T.Taunton and Somerset NHS Foundation Trust]                        -0.0740      0.578     -0.128      0.898      -1.206       1.058
# C(centre_name)[T.The Newcastle Upon Tyne Hospitals NHS Foundation Trust]            0.0029      0.554      0.005      0.996      -1.083       1.089
# C(centre_name)[T.University Hospital of South Manchester]                           0.1795      0.501      0.358      0.720      -0.803       1.162
# C(centre_name)[T.University Hospitals Birmingham NHS Foundation Trust]              2.8173      1.128      2.497      0.013       0.606       5.029
# C(centre_name)[T.Worcestershire Acute Hospitals NHS Trust]                         -0.6011      0.678     -0.887      0.375      -1.929       0.727
# age                                                                                 0.0420      0.009      4.711      0.000       0.025       0.059
# ever_smoked                                                                        -0.0179      0.246     -0.073      0.942      -0.499       0.464
# peto_exposed                                                                       -0.3440      0.270     -1.276      0.202      -0.872       0.184
# ever_smoked:peto_exposed                                                            0.5945      0.321      1.852      0.064      -0.035       1.224
# ===================================================================================================================================================
# Odds Ratios
# ======================
#                                                     2.5%  97.5%    OR
# Intercept                                           0.01   0.22  0.05
# C(centre_name)[T.Aintree University Hospitals N...  0.31   2.16  0.82
# C(centre_name)[T.Glasgow Royal Infirmary]           0.28   9.52  1.63
# C(centre_name)[T.Guys’ and St Thomas’ NHS Found...  0.38   2.87  1.04
# C(centre_name)[T.Heart of England NHS Foundatio...  0.35   2.39  0.91
# C(centre_name)[T.Imperial College Healthcare NH...  0.09   0.66  0.24
# C(centre_name)[T.Leeds Teaching Hospitals NHS T...  3.15  87.73 16.64
# C(centre_name)[T.Morriston Hospital]                0.31   3.30  1.01
# C(centre_name)[T.Norfolk and Norwich University...  0.54  20.15  3.29
# C(centre_name)[T.North Bristol NHS Trust]           0.28   2.12  0.77
# C(centre_name)[T.Nottingham University Hospital...  0.33   2.32  0.87
# C(centre_name)[T.Papworth Hospital NHS Foundati...  0.32   2.27  0.85
# C(centre_name)[T.Portsmouth Hospitals NHS Trust]    0.16   2.87  0.68
# C(centre_name)[T.Royal Devon and Exeter NHS Fou...  0.28   2.68  0.87
# C(centre_name)[T.Royal Infirmary of Edinburgh]      0.25   2.47  0.78
# C(centre_name)[T.Southampton University Hospita...  0.30   2.02  0.78
# C(centre_name)[T.Taunton and Somerset NHS Found...  0.30   2.88  0.93
# C(centre_name)[T.The Newcastle Upon Tyne Hospit...  0.34   2.97  1.00
# C(centre_name)[T.University Hospital of South M...  0.45   3.20  1.20
# C(centre_name)[T.University Hospitals Birmingha...  1.83 152.72 16.73
# C(centre_name)[T.Worcestershire Acute Hospitals...  0.15   2.07  0.55
# age                                                 1.02   1.06  1.04
# ever_smoked                                         0.61   1.59  0.98
# peto_exposed                                        0.42   1.20  0.71
# ever_smoked:peto_exposed                            0.97   3.40  1.81

# %% [markdown]
# # table four

# %%
gt = pd.read_csv('genotyping_cleaned.csv')

transforms = {'Heterozygous':'(G;T)', 'Homozygous Allele 1':'(G;G)', 'Homozygous Allele 2':'(T;T)',
       'Homozygous Allele 1 ':'(G;G)', 'Homoxygous Allele 1':'(G;G)',
       ' Homozygous Allele 2':'(T;T)', ' Homozygous Allele 1':'(G;G)'}
gt.genotype = gt.genotype.map(transforms)

transforms = {"(G;G)":0, "(G;T)":1, "(T;T)":2}

gt.genotype = gt.genotype.map(transforms) # change genotype to 0,1,2 (assumes additive model)

# add genotype
genotype_lookup = gt[['participant_id', 'genotype']]
genotype_lookup.index = genotype_lookup['participant_id']
genotype_lookup = genotype_lookup['genotype'].to_dict()

df['genotype'] = df.participant_id.map(genotype_lookup)

df = df[df['genotype'].notnull()] # restrict analysis to participants with exposure data and genotype

df.loc[:,'minor_allele'] = df['genotype'] > 0

df.loc[:,'minor_allele'] = df.loc[:,'minor_allele'].astype(int)

df.to_csv('flat_data_genotype_subset.csv', index=False)
# Out:
# /home/drcjar/anaconda3/envs/ipfjes/lib/python3.6/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/drcjar/anaconda3/envs/ipfjes/lib/python3.6/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
model = smf.logit('case ~ ever_smoked*peto_exposed', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.687631
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  818
# Model:                          Logit   Df Residuals:                      814
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.007118
# Time:                        23:26:58   Log-Likelihood:                -562.48
# converged:                       True   LL-Null:                       -566.52
# Covariance Type:            nonrobust   LLR p-value:                   0.04469
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.1636      0.203     -0.807      0.420      -0.561       0.234
# ever_smoked                 -0.0070      0.250     -0.028      0.978      -0.497       0.483
# peto_exposed                -0.2613      0.271     -0.964      0.335      -0.793       0.270
# ever_smoked:peto_exposed     0.5461      0.324      1.686      0.092      -0.089       1.181
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.57   1.26 0.85
# ever_smoked               0.61   1.62 0.99
# peto_exposed              0.45   1.31 0.77
# ever_smoked:peto_exposed  0.92   3.26 1.73

# %%
model = smf.logit('case ~ age + ever_smoked*peto_exposed', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.681188
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  818
# Model:                          Logit   Df Residuals:                      813
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.01642
# Time:                        23:26:58   Log-Likelihood:                -557.21
# converged:                       True   LL-Null:                       -566.52
# Covariance Type:            nonrobust   LLR p-value:                 0.0009390
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -2.2855      0.694     -3.296      0.001      -3.645      -0.926
# age                          0.0280      0.009      3.207      0.001       0.011       0.045
# ever_smoked                  0.0163      0.252      0.065      0.948      -0.477       0.510
# peto_exposed                -0.2817      0.273     -1.031      0.302      -0.817       0.254
# ever_smoked:peto_exposed     0.5723      0.326      1.754      0.079      -0.067       1.212
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.03   0.40 0.10
# age                       1.01   1.05 1.03
# ever_smoked               0.62   1.67 1.02
# peto_exposed              0.44   1.29 0.75
# ever_smoked:peto_exposed  0.93   3.36 1.77

# %%
model = smf.logit('case ~ peto_exposed*genotype', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.609092
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  818
# Model:                          Logit   Df Residuals:                      814
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                  0.1205
# Time:                        23:26:58   Log-Likelihood:                -498.24
# converged:                       True   LL-Null:                       -566.52
# Covariance Type:            nonrobust   LLR p-value:                 2.090e-29
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.7667      0.165     -4.660      0.000      -1.089      -0.444
# peto_exposed              0.0283      0.203      0.139      0.889      -0.370       0.427
# genotype                  1.3141      0.237      5.545      0.000       0.850       1.779
# peto_exposed:genotype     0.3587      0.301      1.193      0.233      -0.230       0.948
# =========================================================================================
# Odds Ratios
# ======================
#                        2.5%  97.5%   OR
# Intercept              0.34   0.64 0.46
# peto_exposed           0.69   1.53 1.03
# genotype               2.34   5.92 3.72
# peto_exposed:genotype  0.79   2.58 1.43

# %%
model = smf.logit('case ~ age + ever_smoked + peto_exposed*genotype', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.601945
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  818
# Model:                          Logit   Df Residuals:                      812
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                  0.1308
# Time:                        23:26:59   Log-Likelihood:                -492.39
# converged:                       True   LL-Null:                       -566.52
# Covariance Type:            nonrobust   LLR p-value:                 3.150e-30
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.1146      0.753     -4.136      0.000      -4.590      -1.639
# age                       0.0286      0.009      3.013      0.003       0.010       0.047
# ever_smoked               0.3028      0.173      1.749      0.080      -0.037       0.642
# peto_exposed             -0.0032      0.205     -0.016      0.987      -0.406       0.399
# genotype                  1.3080      0.239      5.465      0.000       0.839       1.777
# peto_exposed:genotype     0.3641      0.303      1.201      0.230      -0.230       0.958
# =========================================================================================
# Odds Ratios
# ======================
#                        2.5%  97.5%   OR
# Intercept              0.01   0.19 0.04
# age                    1.01   1.05 1.03
# ever_smoked            0.96   1.90 1.35
# peto_exposed           0.67   1.49 1.00
# genotype               2.31   5.91 3.70
# peto_exposed:genotype  0.79   2.61 1.44

# %%
model = smf.logit('case ~ ever_smoked*peto_exposed', data=df[df['genotype'] == 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.623635
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  479
# Model:                          Logit   Df Residuals:                      475
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.001926
# Time:                        23:26:59   Log-Likelihood:                -298.72
# converged:                       True   LL-Null:                       -299.30
# Covariance Type:            nonrobust   LLR p-value:                    0.7643
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.9886      0.293     -3.376      0.001      -1.563      -0.415
# ever_smoked                  0.3095      0.357      0.866      0.386      -0.391       1.010
# peto_exposed                 0.1062      0.380      0.279      0.780      -0.639       0.852
# ever_smoked:peto_exposed    -0.1398      0.454     -0.308      0.758      -1.030       0.750
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.21   0.66 0.37
# ever_smoked               0.68   2.74 1.36
# peto_exposed              0.53   2.34 1.11
# ever_smoked:peto_exposed  0.36   2.12 0.87

# %%
model = smf.logit('case ~ age + ever_smoked*peto_exposed', data=df[df['genotype'] == 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.620852
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  479
# Model:                          Logit   Df Residuals:                      474
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                0.006381
# Time:                        23:26:59   Log-Likelihood:                -297.39
# converged:                       True   LL-Null:                       -299.30
# Covariance Type:            nonrobust   LLR p-value:                    0.4310
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -2.4464      0.951     -2.571      0.010      -4.311      -0.582
# age                          0.0195      0.012      1.619      0.106      -0.004       0.043
# ever_smoked                  0.2931      0.358      0.818      0.413      -0.409       0.995
# peto_exposed                 0.0657      0.382      0.172      0.863      -0.683       0.815
# ever_smoked:peto_exposed    -0.0862      0.456     -0.189      0.850      -0.981       0.808
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.01   0.56 0.09
# age                       1.00   1.04 1.02
# ever_smoked               0.66   2.71 1.34
# peto_exposed              0.50   2.26 1.07
# ever_smoked:peto_exposed  0.38   2.24 0.92

# %%
model = smf.logit('case ~ ever_smoked*peto_exposed', data=df[df['genotype'] > 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.575358
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  339
# Model:                          Logit   Df Residuals:                      335
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.03453
# Time:                        23:26:59   Log-Likelihood:                -195.05
# converged:                       True   LL-Null:                       -202.02
# Covariance Type:            nonrobust   LLR p-value:                  0.002970
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    1.0647      0.367      2.903      0.004       0.346       1.783
# ever_smoked                 -0.5867      0.432     -1.358      0.175      -1.434       0.260
# peto_exposed                -0.7646      0.471     -1.625      0.104      -1.687       0.158
# ever_smoked:peto_exposed     1.6512      0.556      2.967      0.003       0.561       2.742
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 1.41   5.95 2.90
# ever_smoked               0.24   1.30 0.56
# peto_exposed              0.19   1.17 0.47
# ever_smoked:peto_exposed  1.75  15.52 5.21

# %%
model = smf.logit('case ~ age + ever_smoked*peto_exposed', data=df[df['genotype'] > 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.564901
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  339
# Model:                          Logit   Df Residuals:                      334
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.05208
# Time:                        23:26:59   Log-Likelihood:                -191.50
# converged:                       True   LL-Null:                       -202.02
# Covariance Type:            nonrobust   LLR p-value:                 0.0003106
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -2.0508      1.239     -1.655      0.098      -4.479       0.378
# age                          0.0403      0.015      2.613      0.009       0.010       0.071
# ever_smoked                 -0.4621      0.440     -1.051      0.293      -1.324       0.399
# peto_exposed                -0.7157      0.477     -1.499      0.134      -1.651       0.220
# ever_smoked:peto_exposed     1.5832      0.564      2.808      0.005       0.478       2.688
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.01   1.46 0.13
# age                       1.01   1.07 1.04
# ever_smoked               0.27   1.49 0.63
# peto_exposed              0.19   1.25 0.49
# ever_smoked:peto_exposed  1.61  14.71 4.87

# %% [markdown]
# # sensitivity analysis

# %%
df = df[df['centre'] != 2] # throw away centre 2 since it contains no genotyped cases

# %%
model = smf.logit('case ~ C(centre) + ever_smoked*peto_exposed', data=df)              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.622960
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  808
# Model:                          Logit   Df Residuals:                      785
# Method:                           MLE   Df Model:                           22
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                  0.1009
# Time:                        23:26:59   Log-Likelihood:                -503.35
# converged:                       True   LL-Null:                       -559.86
# Covariance Type:            nonrobust   LLR p-value:                 3.177e-14
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.0967      0.318     -0.304      0.761      -0.721       0.527
# C(centre)[T.3.0]            -1.1772      0.449     -2.622      0.009      -2.057      -0.297
# C(centre)[T.4.0]            -0.0783      0.310     -0.253      0.801      -0.686       0.529
# C(centre)[T.5.0]             0.2399      0.341      0.705      0.481      -0.428       0.907
# C(centre)[T.6.0]             0.0002      0.342      0.001      0.999      -0.670       0.670
# C(centre)[T.7.0]            -0.1360      0.430     -0.317      0.751      -0.978       0.706
# C(centre)[T.8.0]            -0.0450      0.330     -0.137      0.891      -0.691       0.601
# C(centre)[T.9.0]            -1.4954      0.512     -2.922      0.003      -2.498      -0.492
# C(centre)[T.10.0]           -1.2877      0.351     -3.673      0.000      -1.975      -0.601
# C(centre)[T.11.0]           -0.0963      0.488     -0.197      0.844      -1.054       0.861
# C(centre)[T.12.0]            0.2515      0.804      0.313      0.754      -1.324       1.826
# C(centre)[T.13.0]           -0.3822      0.500     -0.764      0.445      -1.363       0.598
# C(centre)[T.14.0]            0.1385      0.418      0.331      0.740      -0.681       0.958
# C(centre)[T.15.0]            0.0121      0.440      0.027      0.978      -0.850       0.874
# C(centre)[T.16.0]            3.4044      1.042      3.267      0.001       1.362       5.447
# C(centre)[T.17.0]           -0.2434      0.652     -0.373      0.709      -1.522       1.035
# C(centre)[T.18.0]            2.5925      1.066      2.431      0.015       0.503       4.682
# C(centre)[T.19.0]           -0.2401      0.569     -0.422      0.673      -1.356       0.876
# C(centre)[T.20.0]            0.0468      0.364      0.128      0.898      -0.667       0.761
# C(centre)[T.21.0]            1.6403      1.108      1.480      0.139      -0.532       3.812
# ever_smoked                  0.1116      0.273      0.409      0.683      -0.424       0.647
# peto_exposed                -0.1652      0.296     -0.558      0.577      -0.745       0.415
# ever_smoked:peto_exposed     0.3835      0.353      1.088      0.277      -0.308       1.075
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%    OR
# Intercept                 0.49   1.69  0.91
# C(centre)[T.3.0]          0.13   0.74  0.31
# C(centre)[T.4.0]          0.50   1.70  0.92
# C(centre)[T.5.0]          0.65   2.48  1.27
# C(centre)[T.6.0]          0.51   1.95  1.00
# C(centre)[T.7.0]          0.38   2.03  0.87
# C(centre)[T.8.0]          0.50   1.82  0.96
# C(centre)[T.9.0]          0.08   0.61  0.22
# C(centre)[T.10.0]         0.14   0.55  0.28
# C(centre)[T.11.0]         0.35   2.37  0.91
# C(centre)[T.12.0]         0.27   6.21  1.29
# C(centre)[T.13.0]         0.26   1.82  0.68
# C(centre)[T.14.0]         0.51   2.61  1.15
# C(centre)[T.15.0]         0.43   2.40  1.01
# C(centre)[T.16.0]         3.90 232.03 30.10
# C(centre)[T.17.0]         0.22   2.81  0.78
# C(centre)[T.18.0]         1.65 108.01 13.36
# C(centre)[T.19.0]         0.26   2.40  0.79
# C(centre)[T.20.0]         0.51   2.14  1.05
# C(centre)[T.21.0]         0.59  45.25  5.16
# ever_smoked               0.65   1.91  1.12
# peto_exposed              0.47   1.51  0.85
# ever_smoked:peto_exposed  0.74   2.93  1.47

# %%
model = smf.logit('case ~ C(centre) + ever_smoked*peto_exposed', data=df[df['genotype'] == 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.552884
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  470
# Model:                          Logit   Df Residuals:                      447
# Method:                           MLE   Df Model:                           22
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                  0.1216
# Time:                        23:27:00   Log-Likelihood:                -259.86
# converged:                      False   LL-Null:                       -295.82
# Covariance Type:            nonrobust   LLR p-value:                 3.271e-07
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -0.4314      0.444     -0.972      0.331      -1.301       0.439
# C(centre)[T.3.0]            -2.9827      1.071     -2.785      0.005      -5.082      -0.884
# C(centre)[T.4.0]            -0.4339      0.429     -1.012      0.311      -1.274       0.406
# C(centre)[T.5.0]            -0.3747      0.469     -0.799      0.424      -1.294       0.545
# C(centre)[T.6.0]            -0.8747      0.482     -1.814      0.070      -1.820       0.070
# C(centre)[T.7.0]            -0.5937      0.585     -1.016      0.310      -1.739       0.552
# C(centre)[T.8.0]            -0.3248      0.444     -0.732      0.464      -1.195       0.545
# C(centre)[T.9.0]            -1.5416      0.699     -2.205      0.027      -2.912      -0.171
# C(centre)[T.10.0]           -1.5184      0.464     -3.275      0.001      -2.427      -0.610
# C(centre)[T.11.0]           -0.2404      0.653     -0.368      0.713      -1.519       1.039
# C(centre)[T.12.0]            0.1368      1.051      0.130      0.896      -1.923       2.197
# C(centre)[T.13.0]           -0.3689      0.641     -0.575      0.565      -1.626       0.888
# C(centre)[T.14.0]           -0.0430      0.593     -0.073      0.942      -1.205       1.119
# C(centre)[T.15.0]           -0.6680      0.674     -0.991      0.322      -1.989       0.653
# C(centre)[T.16.0]            2.9780      1.078      2.763      0.006       0.866       5.090
# C(centre)[T.17.0]           -0.9245      0.874     -1.057      0.290      -2.638       0.789
# C(centre)[T.18.0]           20.2205    1.3e+04      0.002      0.999   -2.54e+04    2.55e+04
# C(centre)[T.19.0]           -1.7474      1.114     -1.569      0.117      -3.931       0.436
# C(centre)[T.20.0]           -0.5739      0.514     -1.116      0.264      -1.582       0.434
# C(centre)[T.21.0]            0.8782      1.265      0.694      0.488      -1.602       3.358
# ever_smoked                  0.3287      0.395      0.831      0.406      -0.446       1.104
# peto_exposed                 0.3021      0.413      0.731      0.465      -0.508       1.112
# ever_smoked:peto_exposed    -0.4119      0.498     -0.827      0.408      -1.388       0.564
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%             OR
# Intercept                 0.27   1.55           0.65
# C(centre)[T.3.0]          0.01   0.41           0.05
# C(centre)[T.4.0]          0.28   1.50           0.65
# C(centre)[T.5.0]          0.27   1.72           0.69
# C(centre)[T.6.0]          0.16   1.07           0.42
# C(centre)[T.7.0]          0.18   1.74           0.55
# C(centre)[T.8.0]          0.30   1.72           0.72
# C(centre)[T.9.0]          0.05   0.84           0.21
# C(centre)[T.10.0]         0.09   0.54           0.22
# C(centre)[T.11.0]         0.22   2.82           0.79
# C(centre)[T.12.0]         0.15   9.00           1.15
# C(centre)[T.13.0]         0.20   2.43           0.69
# C(centre)[T.14.0]         0.30   3.06           0.96
# C(centre)[T.15.0]         0.14   1.92           0.51
# C(centre)[T.16.0]         2.38 162.45          19.65
# C(centre)[T.17.0]         0.07   2.20           0.40
# C(centre)[T.18.0]         0.00    inf 604,847,950.91
# C(centre)[T.19.0]         0.02   1.55           0.17
# C(centre)[T.20.0]         0.21   1.54           0.56
# C(centre)[T.21.0]         0.20  28.73           2.41
# ever_smoked               0.64   3.01           1.39
# peto_exposed              0.60   3.04           1.35
# ever_smoked:peto_exposed  0.25   1.76           0.66
# /home/drcjar/anaconda3/envs/ipfjes/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /home/drcjar/anaconda3/envs/ipfjes/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.

# %%
model = smf.logit('case ~ age + C(centre) + ever_smoked*peto_exposed', data=df[df['genotype'] > 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.496998
#          Iterations: 35
# /home/drcjar/anaconda3/envs/ipfjes/lib/python3.6/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  338
# Model:                          Logit   Df Residuals:                      314
# Method:                           MLE   Df Model:                           23
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                  0.1632
# Time:                        23:27:00   Log-Likelihood:                -167.99
# converged:                      False   LL-Null:                       -200.76
# Covariance Type:            nonrobust   LLR p-value:                 5.811e-06
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -3.4009      1.477     -2.302      0.021      -6.296      -0.506
# C(centre)[T.3.0]             0.0220      0.678      0.032      0.974      -1.307       1.351
# C(centre)[T.4.0]             0.3208      0.501      0.640      0.522      -0.661       1.303
# C(centre)[T.5.0]             1.2092      0.606      1.996      0.046       0.022       2.396
# C(centre)[T.6.0]             1.8982      0.734      2.587      0.010       0.460       3.336
# C(centre)[T.7.0]             1.0057      0.813      1.237      0.216      -0.588       2.599
# C(centre)[T.8.0]             0.6499      0.558      1.166      0.244      -0.443       1.743
# C(centre)[T.9.0]            -1.2818      0.784     -1.634      0.102      -2.819       0.255
# C(centre)[T.10.0]           -0.0315      0.636     -0.049      0.961      -1.277       1.214
# C(centre)[T.11.0]            0.6029      0.853      0.707      0.480      -1.070       2.276
# C(centre)[T.12.0]            0.6019      1.342      0.448      0.654      -2.029       3.233
# C(centre)[T.13.0]            0.2209      0.857      0.258      0.797      -1.459       1.901
# C(centre)[T.14.0]            0.2185      0.635      0.344      0.731      -1.026       1.463
# C(centre)[T.15.0]            0.7146      0.707      1.011      0.312      -0.671       2.100
# C(centre)[T.16.0]           23.8254   4.29e+04      0.001      1.000    -8.4e+04    8.41e+04
# C(centre)[T.17.0]           22.3212   4.09e+04      0.001      1.000   -8.01e+04    8.02e+04
# C(centre)[T.18.0]            2.5821      1.154      2.238      0.025       0.321       4.843
# C(centre)[T.19.0]            1.3845      1.173      1.181      0.238      -0.914       3.683
# C(centre)[T.20.0]            1.0458      0.638      1.638      0.101      -0.205       2.297
# C(centre)[T.21.0]           22.0633   3.93e+04      0.001      1.000    -7.7e+04     7.7e+04
# age                          0.0478      0.017      2.773      0.006       0.014       0.082
# ever_smoked                 -0.2429      0.493     -0.493      0.622      -1.209       0.723
# peto_exposed                -0.7999      0.536     -1.491      0.136      -1.851       0.251
# ever_smoked:peto_exposed     1.6338      0.635      2.574      0.010       0.390       2.878
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%                OR
# Intercept                 0.00   0.60              0.03
# C(centre)[T.3.0]          0.27   3.86              1.02
# C(centre)[T.4.0]          0.52   3.68              1.38
# C(centre)[T.5.0]          1.02  10.98              3.35
# C(centre)[T.6.0]          1.58  28.11              6.67
# C(centre)[T.7.0]          0.56  13.45              2.73
# C(centre)[T.8.0]          0.64   5.71              1.92
# C(centre)[T.9.0]          0.06   1.29              0.28
# C(centre)[T.10.0]         0.28   3.37              0.97
# C(centre)[T.11.0]         0.34   9.73              1.83
# C(centre)[T.12.0]         0.13  25.36              1.83
# C(centre)[T.13.0]         0.23   6.70              1.25
# C(centre)[T.14.0]         0.36   4.32              1.24
# C(centre)[T.15.0]         0.51   8.17              2.04
# C(centre)[T.16.0]         0.00    inf 22,245,388,259.51
# C(centre)[T.17.0]         0.00    inf  4,942,907,077.72
# C(centre)[T.18.0]         1.38 126.91             13.23
# C(centre)[T.19.0]         0.40  39.75              3.99
# C(centre)[T.20.0]         0.81   9.94              2.85
# C(centre)[T.21.0]         0.00    inf  3,818,990,916.19
# age                       1.01   1.09              1.05
# ever_smoked               0.30   2.06              0.78
# peto_exposed              0.16   1.29              0.45
# ever_smoked:peto_exposed  1.48  17.78              5.12
# /home/drcjar/anaconda3/envs/ipfjes/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.

# %%
model = smf.logit('case ~ age + distfromcentre + ever_smoked*peto_exposed', data=df[df['genotype'] > 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.508122
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  338
# Model:                          Logit   Df Residuals:                      332
# Method:                           MLE   Df Model:                            5
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                  0.1445
# Time:                        23:27:00   Log-Likelihood:                -171.75
# converged:                       True   LL-Null:                       -200.76
# Covariance Type:            nonrobust   LLR p-value:                 3.109e-11
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -3.3860      1.326     -2.553      0.011      -5.985      -0.787
# age                          0.0448      0.016      2.765      0.006       0.013       0.077
# distfromcentre               0.0421      0.009      4.692      0.000       0.024       0.060
# ever_smoked                 -0.2392      0.469     -0.510      0.610      -1.158       0.680
# peto_exposed                -0.4349      0.504     -0.864      0.388      -1.422       0.552
# ever_smoked:peto_exposed     1.2534      0.597      2.100      0.036       0.083       2.423
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.00   0.46 0.03
# age                       1.01   1.08 1.05
# distfromcentre            1.02   1.06 1.04
# ever_smoked               0.31   1.97 0.79
# peto_exposed              0.24   1.74 0.65
# ever_smoked:peto_exposed  1.09  11.28 3.50

# %%
model = smf.logit('case ~ age + ever_smoked*C(lowest_peto_cat_reordered)', data=df[df['genotype'] > 0])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.555014
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  338
# Model:                          Logit   Df Residuals:                      327
# Method:                           MLE   Df Model:                           10
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.06556
# Time:                        23:27:00   Log-Likelihood:                -187.59
# converged:                       True   LL-Null:                       -200.76
# Covariance Type:            nonrobust   LLR p-value:                  0.003327
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# Intercept                                        -2.3776      1.335     -1.781      0.075      -4.995       0.239
# C(lowest_peto_cat_reordered)[T.2]                 0.1363      0.745      0.183      0.855      -1.323       1.596
# C(lowest_peto_cat_reordered)[T.3]                -0.7407      0.673     -1.101      0.271      -2.059       0.578
# C(lowest_peto_cat_reordered)[T.4]                -0.1005      0.762     -0.132      0.895      -1.595       1.394
# C(lowest_peto_cat_reordered)[T.5]                -1.4879      0.944     -1.577      0.115      -3.338       0.362
# age                                               0.0437      0.016      2.755      0.006       0.013       0.075
# ever_smoked                                      -0.3649      0.644     -0.566      0.571      -1.627       0.898
# ever_smoked:C(lowest_peto_cat_reordered)[T.2]    -0.1690      0.884     -0.191      0.848      -1.901       1.563
# ever_smoked:C(lowest_peto_cat_reordered)[T.3]     1.5762      0.827      1.906      0.057      -0.044       3.197
# ever_smoked:C(lowest_peto_cat_reordered)[T.4]     1.3163      0.907      1.452      0.147      -0.461       3.093
# ever_smoked:C(lowest_peto_cat_reordered)[T.5]     1.8784      1.075      1.747      0.081      -0.230       3.986
# =================================================================================================================
# Odds Ratios
# ======================
#                                                2.5%  97.5%   OR
# Intercept                                      0.01   1.27 0.09
# C(lowest_peto_cat_reordered)[T.2]              0.27   4.93 1.15
# C(lowest_peto_cat_reordered)[T.3]              0.13   1.78 0.48
# C(lowest_peto_cat_reordered)[T.4]              0.20   4.03 0.90
# C(lowest_peto_cat_reordered)[T.5]              0.04   1.44 0.23
# age                                            1.01   1.08 1.04
# ever_smoked                                    0.20   2.45 0.69
# ever_smoked:C(lowest_peto_cat_reordered)[T.2]  0.15   4.77 0.84
# ever_smoked:C(lowest_peto_cat_reordered)[T.3]  0.96  24.46 4.84
# ever_smoked:C(lowest_peto_cat_reordered)[T.4]  0.63  22.05 3.73
# ever_smoked:C(lowest_peto_cat_reordered)[T.5]  0.79  53.86 6.54

# %%
model = smf.logit('case ~ age + ever_smoked*peto_exposed', data=df[df['genotype'] == 1])              
result = model.fit()
print(result.summary())
print ("Odds Ratios")
print ("======================")
params = result.params
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print(np.exp(conf))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.572322
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   case   No. Observations:                  302
# Model:                          Logit   Df Residuals:                      297
# Method:                           MLE   Df Model:                            4
# Date:                Sun, 06 Sep 2020   Pseudo R-squ.:                 0.06049
# Time:                        23:27:00   Log-Likelihood:                -172.84
# converged:                       True   LL-Null:                       -183.97
# Covariance Type:            nonrobust   LLR p-value:                 0.0001781
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -2.5067      1.309     -1.916      0.055      -5.071       0.058
# age                          0.0464      0.016      2.831      0.005       0.014       0.079
# ever_smoked                 -0.5234      0.462     -1.132      0.258      -1.430       0.383
# peto_exposed                -0.8041      0.499     -1.613      0.107      -1.781       0.173
# ever_smoked:peto_exposed     1.6805      0.590      2.849      0.004       0.524       2.837
# ============================================================================================
# Odds Ratios
# ======================
#                           2.5%  97.5%   OR
# Intercept                 0.01   1.06 0.08
# age                       1.01   1.08 1.05
# ever_smoked               0.24   1.47 0.59
# peto_exposed              0.17   1.19 0.45
# ever_smoked:peto_exposed  1.69  17.06 5.37
